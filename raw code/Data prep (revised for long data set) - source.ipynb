# %% [markdown]
# # Data compiling

# %% [markdown]
# This notebook lives in the folder where all the data is stored.  It takes the html files and parses them looking for plaintiff, defendant, and location data.  When it's done, it stores all the given information in a pandas dataframe.

# %%
import os
import re
import time
import pandas as pd
from collections import defaultdict

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  'census_data.csv',
#  'Data prep (revised for long data).ipynb',
#  'Housing',
#  'Housing - Copy.zip',
#  'housing downloader',
#  "Processing Bill's data.ipynb",
#  'Richards thesis.pdf',
#  'thesis',
#  'Thesis work']

# %%
os.getcwd()
# Out:
# '/Users/josephgpalin/Desktop/transfer/thesis'

# %%
if "Housing" not in os.getcwd():
    os.chdir("Housing")
os.listdir()[:20]
# Out:
# ['.DS_Store',
#  '01H77SP000080.html',
#  '01H77SP002057.html',
#  '01H77SP003928.html',
#  '01H79SP000314.html',
#  '01H79SP001985.html',
#  '01H79SP002790.html',
#  '01H79SP003298.html',
#  '01H79SP003684.html',
#  '01H83SP00148.html',
#  '01H83SP02521.html',
#  '01H83SP03328.html',
#  '01H84SP000363.html',
#  '01H84SP000684.html',
#  '01H84SP000700.html',
#  '01H84SP003575.html',
#  '01H84SP003637.html',
#  '01H84SP003898.html',
#  '01H85SP002199.html',
#  '01H85SP003707.html']

# %%
# get the first file name for parsing
first = os.listdir()[1]

# %%
first
# Out:
# '01H77SP000080.html'

# %%
with open(first,"r") as f:
    source = f.read()

# %%
# the source for the page.
source
# Out:
# '<!DOCTYPE html>\n<html>\n<!-- $Id: EServiceBaseLayoutPage.html,v 1.11 2015/07/17 21:22:42 zcarter Exp $ -->\n<head>\n    <meta http-equiv="X-UA-Compatible" content="IE=edge"/>\n\t<meta http-equiv="Content-Type" content="text/html;charset=UTF-8"/>\n\t<meta name="viewport" content="width=device-width; initial-scale=1.0; maximum-scale=1.0;">\n\t<title>Massachusetts Trial Court</title>\n\t<script type="text/javascript">window.cjsBrowserRenderStartTime = new Date();</script>\n\t<link rel="icon" type="image/png" href="../images/favicon.ico"/>\n\t<link rel="stylesheet" type="text/css" href="css/eaccess.css?v=1.18.05" media="screen"/>\n\t<link rel="stylesheet" type="text/css" href="css/initialize.css?v=1.18.05" media="screen"/>\n\t<link rel="stylesheet" type="text/css" href="css/eServ_fonts.css?v=1.18.05" media="screen"/>\n\t<link rel="stylesheet" type="text/css" href="css/eServ_header.css?v=1.18.05" media="screen"/>\n\t<link rel="stylesheet" type="text/css" href="css/eServ_application.css?v=1.18.05" media="screen"/>\n\t<link rel="stylesheet" type="text/css" href="css/eServ_globalNav.css?v=1.18.05" media="screen"/>\n\t<link rel="stylesheet" type="text/css" href="css/eServ_footer.css?v=1.18.05" media="screen"/>\n\t<link rel="stylesheet" type="text/css" href="css/eServ_forms.css?v=1.18.05" media="screen"/>\n\t<link rel="stylesheet" type="text/css" href="css/eServ_containers.css?v=1.18.05" media="screen"/>\n\t<link rel="stylesheet" type="text/css" href="css/eServ_tables.css?v=1.18.05" media="screen"/>\n\t<link rel="stylesheet" type="text/css" href="css/eServ_buttons.css?v=1.18.05" media="screen"/>\n\t<link rel="stylesheet" type="text/css" href="css/efile.css?v=1.18.05" media="screen"/>\n\t<link rel="stylesheet" type="text/css" href="css/epay.css?v=1.18.05" media="screen"/>\n\t<link rel="stylesheet" type="text/css" href="css/eServ_Calendar.css?v=1.18.05" media="screen"/>\n\t<link rel="stylesheet" type="text/css" href="css/eServ_configStyles.css?v=1.18.05" media="screen"/>\n\t<link rel="stylesheet" type="text/css" href="css/eServ_PortalDashboard.css?v=1.18.05" media="screen"/>\n\t<link rel="stylesheet" type="text/css" href="css/eServ_NotifyPage.css?v=1.18.05" media="screen"/>\n\t<link rel="stylesheet" type="text/css" href="css/eServ_printStyle.css?v=1.18.05" media="print"/>\n\t<link href="css/eServ_Phone.css?v=1.18.05" rel="stylesheet" type="text/css" media="only screen and (min-device-width:0px) and (max-device-width:380px)"/>\n\t<link href="css/eServ_Tablet.css?v=1.18.05" rel="stylesheet" type="text/css" media="only screen and (min-device-width:381px) and (max-device-width:900px)">\n\t<link rel="stylesheet" href="../font-awesome/css/font-awesome.min.css">\n  <!--[if lte IE 7]>\n\t\n\t<style type="text/css">\n\t.ui-dropdown-content ul ul li { display: inline; width: 100%; }\n\t.ui-dropdown-content ul ul li a { border-right: none; width: 100%; display: inline-block; }\n\t</style>\n  <![endif]-->\n<script type="text/javascript" src="../resources/org.odlabs.wiquery.core.commons.CoreJavaScriptResourceReference/jquery/jquery-1.5.1.min.js"></script>\n<link rel="stylesheet" type="text/css" href="../resources/org.odlabs.wiquery.ui.themes.WiQueryCoreThemeResourceReference/uilightness/jquery-ui-1.8.10.custom.css" />\n<script type="text/javascript" src="../resources/org.odlabs.wiquery.ui.core.CoreUIJavaScriptResourceReference/jquery.ui.core.min.js"></script>\n<script type="text/javascript" src="../resources/com.cjs.wicket.core.wiquery.plugin.layout.LayoutJQueryUICustomJavaScriptResourceReference/jquery.ui.custom.js"></script>\n<script type="text/javascript" src="../resources/com.cjs.wicket.core.wiquery.plugin.layout.LayoutJavaScriptResourceReference/jquery.layout.js"></script>\n<script type="text/javascript" src="../resources/com.cjs.wicket.core.wiquery.plugin.window.WindowJavaScriptResourceReference/jquery.window.js"></script>\n<script type="text/javascript" src="../resources/org.odlabs.wiquery.ui.widget.WidgetJavascriptResourceReference/jquery.ui ...

# %% [markdown]
# I need to extract the actual data.  Beautiful soup?

# %%
"Northeast Housing" in source
# Out:
# True

# %%
# Import beautiful soup
import bs4

# turn the html into soup we can parse
test = bs4.BeautifulSoup(source,"html.parser")

# %%
# Take a look at the soup.  It's not very useful
print(test.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <!-- $Id: EServiceBaseLayoutPage.html,v 1.11 2015/07/17 21:22:42 zcarter Exp $ -->
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width; initial-scale=1.0; maximum-scale=1.0;" name="viewport"/>
#   <title>
#    Massachusetts Trial Court
#   </title>
#   <script type="text/javascript">
#    window.cjsBrowserRenderStartTime = new Date();
#   </script>
#   <link href="../images/favicon.ico" rel="icon" type="image/png"/>
#   <link href="css/eaccess.css?v=1.18.05" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="css/initialize.css?v=1.18.05" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="css/eServ_fonts.css?v=1.18.05" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="css/eServ_header.css?v=1.18.05" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="css/eServ_application.css?v=1.18.05" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="css/eServ_globalNav.css?v=1.18.05" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="css/eServ_footer.css?v=1.18.05" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="css/eServ_forms.css?v=1.18.05" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="css/eServ_containers.css?v=1.18.05" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="css/eServ_tables.css?v=1.18.05" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="css/eServ_buttons.css?v=1.18.05" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="css/efile.css?v=1.18.05" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="css/epay.css?v=1.18.05" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="css/eServ_Calendar.css?v=1.18.05" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="css/eServ_configStyles.css?v=1.18.05" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="css/eServ_PortalDashboard.css?v=1.18.05" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="css/eServ_NotifyPage.css?v=1.18.05" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="css/eServ_printStyle.css?v=1.18.05" media="print" rel="stylesheet" type="text/css"/>
#   <link href="css/eServ_Phone.css?v=1.18.05" media="only screen and (min-device-width:0px) and (max-device-width:380px)" rel="stylesheet" type="text/css"/>
#   <link href="css/eServ_Tablet.css?v=1.18.05" media="only screen and (min-device-width:381px) and (max-device-width:900px)" rel="stylesheet" type="text/css"/>
#   <link href="../font-awesome/css/font-awesome.min.css" rel="stylesheet"/>
#   <!--[if lte IE 7]>
#
# 	<style type="text/css">
# 	.ui-dropdown-content ul ul li { display: inline; width: 100%; }
# 	.ui-dropdown-content ul ul li a { border-right: none; width: 100%; display: inline-block; }
# 	</style>
#   <![endif]-->
#   <script src="../resources/org.odlabs.wiquery.core.commons.CoreJavaScriptResourceReference/jquery/jquery-1.5.1.min.js" type="text/javascript">
#   </script>
#   <link href="../resources/org.odlabs.wiquery.ui.themes.WiQueryCoreThemeResourceReference/uilightness/jquery-ui-1.8.10.custom.css" rel="stylesheet" type="text/css">
#    <script src="../resources/org.odlabs.wiquery.ui.core.CoreUIJavaScriptResourceReference/jquery.ui.core.min.js" type="text/javascript">
#    </script>
#    <script src="../resources/com.cjs.wicket.core.wiquery.plugin.layout.LayoutJQueryUICustomJavaScriptResourceReference/jquery.ui.custom.js" type="text/javascript">
#    </script>
#    <script src="../resources/com.cjs.wicket.core.wiquery.plugin.layout.LayoutJavaScriptResourceReference/jquery.layout.js" type="text/javascript">
#    </script>
#    <script src="../resources/com.cjs.wicket.core.wiquery.plugin.window.WindowJavaScriptResourceReference/jquery.window.js" type="text/javascript">
#    </script>
#    <script src="../resources/org.odlabs.wiquery.ui.widget.WidgetJavascriptResourceReference/jquery.ui.widget.min.js" type="text/javascript">
#    </script>
#    <script src="../resources/org.odlabs.wiquery.ui.mouse.MouseJavascriptResourceReference/jquery.ui.mouse.min.js" type="text/javascript">
#    </script>
#    <script src="../resources/org.odlabs.wiquery.ui.position.PositionJavascriptResourceReference/jquery.ui.position.min.js" type="text/javascript">
#    </script>
#    <script src="../resources/org.odlabs.wiquery.ui.dialog.DialogJavaScriptResourceReference/jquery.ui.dialog.min.js" type="text/javascript">
#    </script>
#    <script src="../resources/org.odlabs.wiquery.ui.button.ButtonJavascriptResourceReference/jquery.ui.button.min.js" type="text/javascript">
#    </script>
#    <script src="../resources/org.odlabs.wiquery.ui.draggable.DraggableJavaScriptResourceReference/jquery.ui.draggable.min.js" type="text/javascript">
#    </script>
#    <script src="../resources/org.odlabs.wiquery.ui.resizable.ResizableJavaScriptResourceReference/jquery.ui.resizable.min.js" type="text/javascript">
#    </script>
#    <script src="../resources/com.cjs.wicket.core.wiquery.plugin.tablesorter.TablesorterJavaScriptResourceReference/jquery.tablesorter.js" type="text/javascript">
#    </script>
#    <script src="../resources/com.cjs.wicket.core.wiquery.plugin.tablesorter.TablesorterParsersJavaScriptResourceReference/jquery.tablesorter.parsers.js" type="text/javascript">
#    </script>
#    <script src="../resources/com.cjs.wicket.core.wiquery.plugin.tablesorter.TablesorterMetadataJavaScriptResourceReference/jquery.metadata.js" type="text/javascript">
#    </script>
#    <link href="../resources/com.cjs.wicket.core.wiquery.plugin.BodyLayoutPlugin/layout/jquery.layout.css" rel="stylesheet" type="text/css">
#     <link href="../resources/com.cjs.wicket.core.wiquery.plugin.window.WindowCSSResourceReference/jquery.window.css" rel="stylesheet" type="text/css"/>
#     <link href="../resources/com.cjs.wicket.core.wiquery.plugin.tablesorter.TablesorterCSSResourceReference/jquery.tablesorter.css" rel="stylesheet" type="text/css"/>
#     <script id="wiquery-gen-1474479515722" type="text/javascript">
#      <!--/*--><![CDATA[/*><!--*/
# (function($) {
# $(document).ready(function() {
# window.bodyLayout=$('#body').layout({name: 'bodyLayout', defaults: {size: 'auto', minSize: 50, paneClass: 'pane', resizerClass: 'resizer', togglerClass: 'toggler', buttonClass: 'button', togglerLength_open: 35, togglerLength_closed: 35, fxName: 'slide', contentSelector: '.content', contentIgnoreSelector: 'span', hideTogglerOnSlide: true, togglerTip_open: 'Close This Pane', togglerTip_closed: 'Open This Pane', resizerTip: 'Resize This Pane', fxSpeed_open: 750, fxSpeed_close: 1500, fxSettings_open: { easing: 'easeInQuint' }, fxSettings_close: { easing: 'easeInQuint' }}, north: {size: 'auto', minSize: 82, closable: false, resizable: false, slidable: false, spacing_open: 0, togglerLength_closed: -1, fxName: 'none'}, south: {size: 'auto', maxSize: 44, closable: false, resizable: false, slidable: false, spacing_open: 0, togglerLength_closed: -1, fxName: 'none'}, east: {initHidden: true, paneSelector: '#EastPane', size: 'auto'}, west: {size: 'auto', minSize: 200, togglerTip_open: 'Close Navigations', togglerTip_closed: 'Open Navigations', resizerTip: 'Resize Navigations', closable: true, resizable: true, fxName: 'none', paneSelector: '#WestPane', initClosed: true, slidable: true, slideTrigger_open: 'click', slideTrigger_close: 'click', togglerAlign_open: 'center', togglerAlign_closed: 'center'}, center: {paneSelector: '#mainContent'}});
# $('#id11e5').dialog({autoOpen: false, position: 'center', open: function(event, ui) {
# $('#id11e5').parents('.ui-dialog:first').find('.ui-dialog-titlebar-close').hide();
# }, minimizable: false, maximizable: false, modal: true, resizable: false, title: 'Please Wait...'});
# $('#id11f0').tablesorter({debug: false, headers: { 0: { sorter: 'cjsDate'}, 1: { sorter: 'text'}, 2: { sorter: 'text'}, 3: { sorter: 'text'}, 4: { sorter: 'text'}, 5: { sorter: 'text'} } , dateFormat: 'mm/dd/yyyy', widgets: ['zebraNested'], widgetZebra: {css: ['roweven','rowodd']}});
# $('#id11f1').tablesorter({debug: false, headers: { 0: { sorter: 'cjsDate'}, 1: { sorter: false}, 2: { sorter: 'text'} } , dateFormat: 'mm/dd/yyyy', widgets: ['zebraNested'], widgetZebra: {css: ['roweven','rowodd']}});
# $('#id11f2').tablesorter({debug: false, headers: { 0: { sorter: 'text'}, 1: { sorter: 'cjsDate'} } , dateFormat: 'mm/dd/yyyy', widgets: ['zebraNested'], widgetZebra: {css: ['roweven','rowodd']}});
# $('#id11f3').tablesorter({debug: false, headers: { 0: { sorter: 'cjsDate'}, 1: { sorter: 'text'}, 2: { sorter: 'text'}, 3: { sorter: 'text'}, 4: { sorter: 'text'} } , dateFormat: 'mm/dd/yyyy', widgets: ['zebraNested'], widgetZebra: {css: ['roweven','rowodd']}});
# });
# })(jQuery);
#
# /*-->]]>*/
#     </script>
#     <script src="../resources/org.apache.wicket.markup.html.WicketEventReference/wicket-event.js" type="text/javascript">
#     </script>
#     <script src="../resources/org.apache.wicket.ajax.WicketAjaxReference/wicket-ajax.js" type="text/javascript">
#     </script>
#     <script id="closeDialogJS" type="text/javascript">
#      <!--/*--><![CDATA[/*><!--*/
# $('#id11e5').dialog('close');
# /*-->]]>*/
#     </script>
#     <script src="../resources/com.cjs.wicket.component.CancelEventPropagationResource/CancelEventPropagation.js" type="text/javascript">
#     </script>
#     <script src="../resources/org.apache.wicket.extensions.ajax.markup.html.modal.ModalWindow/res/modal.js" type="text/javascript">
#     </script>
#     <link href="../resources/org.apache.wicket.extensions.ajax.markup.html.modal.ModalWindow/res/modal.css" rel="stylesheet" type="text/css"/>
#    </link>
#   </link>
#  </head>
#  <body id="body">
#   <div class="ui-layout-north">
#    <div id="header">
#     <div class="globalNavigation" id="id11f4">
#      <ul class="MenuBarHorizontal" id="navigationSectionLeft">
#       <!--
# 	<li wicket:id="menu"></li>
# -->
#       <li class="navLoggedInUser">
#        <a href="#" id="id11f5" onclick="var wcall=wicketAjaxGet('../?x=8DatfxovrgUazXIMhwQe0lMnRyK4FbTZSV*VTf0NLyx-XO-iwSICkrRmXnuD*YnlIpQkVwXRcjkV7biMwzQdBWsSv-B8HJ4FS*iQNPVeAddjOL*gDQQFR-wpG5uMWt5E',function() { }.bind(this),function() { }.bind(this), function() {return Wicket.$('id11f5') != null;}.bind(this));return !wcall;" title="Your Account">
#         <span title="Manage Your Account">
#         </span>
#        </a>
#       </li>
#       <li>
#        <a class="link" href="../home.page">
#         Home
#        </a>
#       </li>
#       <li>
#        <a class="link" href="../?x=8DatfxovrgUazXIMhwQe0lMnRyK4FbTZSV*VTf0NLyx-XO-iwSICkoNmPeeB9GNiPxetThafyit9g06fE9afhRvRdNTX0NYq3R03Fo3dAejDOCA71EhPHQ">
#         Search
#        </a>
#       </li>
#       <li>
#        <a class="link" href="../?x=8DatfxovrgUazXIMhwQe0lMnRyK4FbTZSV*VTf0NLyx-XO-iwSICkmvQbt92dZ3eHjhB6OpeZpNVWigURMn5IVk0jZjdqu3vSHDfpgofgKCSuiFGW8qqsw" title="Search Results">
#         Results
#        </a>
#       </li>
#       <li>
#       </li>
#      </ul>
#      <ul class="MenuBarHorizontal" id="navigationSectionRight">
#       <li>
#        <a class="link" href="../login.page" id="id11f6">
#         Log on
#        </a>
#       </li>
#       <li class="link">
#        <span class="print" id="printLink" onclick="return window.print();" title="Print">
#        </span>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </div>
#   <div class="ui-layout-west" id="WestPane">
#    <div>
#     <div class="dynamicNav" id="id11f7">
#      <div class="menuSection">
#       <div class="sectionHeader">
#        <h3>
#         <span title="">
#          Links
#         </span>
#        </h3>
#       </div>
#       <ul class="menuLinks">
#        <li>
#         <span>
#          <a href="http://www.mass.gov/courts/pdfreportnew.html" title="">
#           Land Court Reports
#          </a>
#         </span>
#        </li>
#        <li>
#         <span>
#          <a href="http://www.mass.gov/courts/eaccess-email.html" title="">
#           Email a Question
#          </a>
#         </span>
#        </li>
#        <li>
#         <span>
#          <a href="http://survey.vovici.com/se/54861F09525D6589" title="">
#           Feedback Survey
#          </a>
#         </span>
#        </li>
#        <li>
#         <span>
#          <a href="http://www.mass.gov/courts/detailed-instructions.html" title="">
#           Detailed Instructions
#          </a>
#         </span>
#        </li>
#        <li>
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="ui-layout-east" id="EastPane">
#   </div>
#   <div id="mainContent">
#    <div id="caseDetail">
#     <div id="caseDetailHeader">
#      <div class="sectionHeader">
#       <h2>
#        01H77SP000080 Silverio, John vs. Duong Au, Phat
#       </h2>
#      </div>
#      <div class="caseInfo formSec bgClr1" id="caseHeaderJMAX">
#       <div class="caseInfoItems">
#        <!--dl-->
#        <dt>
#         Case Type
#        </dt>
#        <dd class="displayData">
#         Housing Court Summary Process
#        </dd>
#        <dt>
#         Initiating Action:
#        </dt>
#        <dd class="displayData">
#         SP Summons and Complaint - Non-payment of Rent
#        </dd>
#        <dt>
#         Case Status
#        </dt>
#        <dd class="displayData">
#         Closed
#        </dd>
#        <dt>
#         Status Date:
#        </dt>
#        <dd class="displayData">
#         01/26/2001
#        </dd>
#        <dt>
#         File Date
#        </dt>
#        <dd class="displayData">
#         01/09/2001
#        </dd>
#        <dt>
#         Case Judge:
#        </dt>
#        <dd class="displayData">
#         Kerman, Hon. David D
#        </dd>
#        <dt>
#         DCM Track:
#        </dt>
#        <dd class="displayData">
#        </dd>
#        <dt>
#         Next Event:
#        </dt>
#        <dd class="displayData">
#         <!-- $Id: CourtViewNextEventPanel.html,v 1.1 2011/04/12 18:55:38 stheisen Exp $ -->
#         <span>
#         </span>
#        </dd>
#        <!--/dl-->
#       </div>
#       <dd class="displayData">
#        <!-- added -->
#        <div class="housingPropertyDetailBox subsection3">
#         <!-- was caseInfoDetailBox -->
#         <div class="additionalCaseInfoPanel">
#          <div class="subSectionHeader2">
#           <h4>
#            <span>
#             Property Address
#            </span>
#           </h4>
#          </div>
#          <div id="addressInfo containerSpacing">
#           <span>
#            279
#           </span>
#           <span>
#           </span>
#           <span>
#           </span>
#           <span>
#           </span>
#           <span>
#            2nd Floor
#           </span>
#           <br/>
#           <span>
#            Lawrence
#           </span>
#           <span>
#            MA
#           </span>
#           <span>
#            01843
#           </span>
#          </div>
#         </div>
#        </div>
#       </dd>
#       <div class="buttonBar">
#        <div id="id11f8">
#        </div>
#        <div id="id11f9" style="display:none">
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="tabSection">
#      <div id="id11fa">
#       <div class="tab-row">
#        <ul>
#         <li class="tab0 selected">
#          <a href="../?x=8DatfxovrgUazXIMhwQe0uhC*1MgPseQVWNUIsIyxNbgG54Of7NPxOi*mfyf*fpz4zZX6Yxh*xZj5BMrBlwxvEtcnHGLArBTvtbfUmQXVQ1vu0JI9YJ6G7YsW0nTmn12" id="id11fb" onclick="var wcall=wicketAjaxGet('../?x=8DatfxovrgUazXIMhwQe0uhC*1MgPseQVWNUIsIyxNbgG54Of7NPxOi*mfyf*fpz4zZX6Yxh*xZj5BMrBlwxvEtcnHGLArBTtenhUyG9hox0tliOCNvOtA64n7MFOZnc',function() { }.bind(this),function() { }.bind(this), function() {return Wicket.$('id11fb') != null;}.bind(this));return !wcall;">
#           <span>
#            All Information
#           </span>
#          </a>
#         </li>
#         <li class="tab1">
#          <a href="../?x=8DatfxovrgUazXIMhwQe0uhC*1MgPseQVWNUIsIyxNbgG54Of7NPxOi*mfyf*fpz4zZX6Yxh*xZj5BMrBlwxvEIBl5oHiOw3EbM15uH3XborED3qgf2lAdxnLweiRcP1" id="id11fc" onclick="var wcall=wicketAjaxGet('../?x=8DatfxovrgUazXIMhwQe0uhC*1MgPseQVWNUIsIyxNbgG54Of7NPxOi*mfyf*fpz4zZX6Yxh*xZj5BMrBlwxvEIBl5oHiOw3Xj9ePsJ0YxyibZg9aUpzieUOpHS*eDjQ',function() { }.bind(this),function() { }.bind(this), function() {return Wicket.$('id11fc') != null;}.bind(this));return !wcall;">
#           <span>
#            Party
#           </span>
#          </a>
#         </li>
#         <li class="tab2">
#          <a href="../?x=8DatfxovrgUazXIMhwQe0uhC*1MgPseQVWNUIsIyxNbgG54Of7NPxOi*mfyf*fpz4zZX6Yxh*xZj5BMrBlwxvM1wC7*zypmxjCF0XMVy0jzrZT-XbzFtRh1dqVoXyRgz" id="id11fd" onclick="var wcall=wicketAjaxGet('../?x=8DatfxovrgUazXIMhwQe0uhC*1MgPseQVWNUIsIyxNbgG54Of7NPxOi*mfyf*fpz4zZX6Yxh*xZj5BMrBlwxvM1wC7*zypmxrXwc6fa*8ejnMwxUZfipXbiOg84l5yrA',function() { }.bind(this),function() { }.bind(this), function() {return Wicket.$('id11fd') != null;}.bind(this));return !wcall;">
#           <span>
#            Event
#           </span>
#          </a>
#         </li>
#         <li class="tab3">
#          <a href="../?x=8DatfxovrgUazXIMhwQe0uhC*1MgPseQVWNUIsIyxNbgG54Of7NPxOi*mfyf*fpz4zZX6Yxh*xZj5BMrBlwxvCUEZNxPkrjNTvX8-Yef5JOA1I1VzMRFqS8QVMl1O5ae" id="id11fe" onclick="var wcall=wicketAjaxGet('../?x=8DatfxovrgUazXIMhwQe0uhC*1MgPseQVWNUIsIyxNbgG54Of7NPxOi*mfyf*fpz4zZX6Yxh*xZj5BMrBlwxvCUEZNxPkrjNO7NckIZ8rCRS7mdC34dTQ*fNy4nf0awP',function() { }.bind(this),function() { }.bind(this), function() {return Wicket.$('id11fe') != null;}.bind(this));return !wcall;">
#           <span>
#            Docket
#           </span>
#          </a>
#         </li>
#         <li class="tab4">
#          <a href="../?x=8DatfxovrgUazXIMhwQe0uhC*1MgPseQVWNUIsIyxNbgG54Of7NPxOi*mfyf*fpz4zZX6Yxh*xZj5BMrBlwxvH7AD5tER8LNSA*rzhOMrkPZmxewrveRh0bpZPobjW6i" id="id11ff" onclick="var wcall=wicketAjaxGet('../?x=8DatfxovrgUazXIMhwQe0uhC*1MgPseQVWNUIsIyxNbgG54Of7NPxOi*mfyf*fpz4zZX6Yxh*xZj5BMrBlwxvH7AD5tER8LNGdj2RsvSD0yMD072LO0s185Y1my94hwX',function() { }.bind(this),function() { }.bind(this), function() {return Wicket.$('id11ff') != null;}.bind(this));return !wcall;">
#           <span>
#            Disposition
#           </span>
#          </a>
#         </li>
#         <li class="tab5 last">
#          <a href="../?x=8DatfxovrgUazXIMhwQe0uhC*1MgPseQVWNUIsIyxNbgG54Of7NPxOi*mfyf*fpz4zZX6Yxh*xZj5BMrBlwxvHbDgF8Of0hl-DYOmuPqxwru*dkJaAQ-qgMiSCjHJW3E" id="id1200" onclick="var wcall=wicketAjaxGet('../?x=8DatfxovrgUazXIMhwQe0uhC*1MgPseQVWNUIsIyxNbgG54Of7NPxOi*mfyf*fpz4zZX6Yxh*xZj5BMrBlwxvHbDgF8Of0hlpfEU4dILsewOu-GkJaVshZcSiSD0jAJ5',function() { }.bind(this),function() { }.bind(this), function() {return Wicket.$('id1200') != null;}.bind(this));return !wcall;">
#           <span>
#            Judgment
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="tab-panel">
#        <div class="allInfoPanel" id="id1201">
#         <div id="id1202" style="display:none">
#         </div>
#         <div id="id1203" style="display:none">
#         </div>
#         <div class="subsection2 bgClr1" id="ptyInfo">
#          <div class="subSectionHeader">
#           <h4>
#            Party Information
#           </h4>
#          </div>
#          <div class="infoChildSection" id="ptyContainer">
#           <div class="rowodd">
#            <div class="subSectionHeader2">
#             <h5>
#              Silverio, John
#              <span class="ptyType">
#               - Plaintiff
#              </span>
#             </h5>
#            </div>
#            <div class="box ptyAffl">
#             <h5>
#              Alias
#             </h5>
#            </div>
#            <div class="box ptyAtty">
#             <h5>
#              Party Attorney
#             </h5>
#             <div class="rowodd">
#              <dl>
#               <dt>
#                Attorney
#               </dt>
#               <dd class="displayData">
#                Pro Se
#               </dd>
#               <dt>
#                Bar Code
#               </dt>
#               <dd class="displayData">
#                PROPER
#               </dd>
#               <dt>
#                Address
#               </dt>
#               <dt>
#                Phone Number
#               </dt>
#               <dd class="displayData">
#               </dd>
#              </dl>
#             </div>
#            </div>
#            <div class="moreInfo ptyMore">
#             <a href="#" id="id1204" onclick="var wcall=wicketAjaxGet('../?x=8DatfxovrgUazXIMhwQe0uhC*1MgPseQVWNUIsIyxNbgG54Of7NPxK3AN2zDEuyKtyHlwEWlW0iuat9*qvhUmYHqYhMDWyaLPUCJr3K8t3y6x4-shOOl7-cB42sDAMzEfDx*vbcci6ZM20befOFkDFeEDV32ofMM16Q5orCr1fd9hJxdjyZwsg',function() { }.bind(this),function() { }.bind(this), function() {return Wicket.$('id1204') != null;}.bind(this));return !wcall;">
#              More Party Information
#             </a>
#            </div>
#            <div class="moreInfo">
#            </div>
#            <div class="moreInfo">
#            </div>
#            <div style="display:none;">
#             This is tooltip Text.  It should display nicely.
#            </div>
#           </div>
#           <div class="roweven">
#            <div class="subSectionHeader2">
#             <h5>
#              Duong Au, Phat
#              <span class="ptyType">
#               - Defendant
#              </span>
#             </h5>
#            </div>
#            <div class="box ptyAffl">
#             <h5>
#              Alias
#             </h5>
#            </div>
#            <div class="box ptyAtty">
#             <h5>
#              Party Attorney
#             </h5>
#             <div class="rowodd">
#              <dl>
#               <dt>
#                Attorney
#               </dt>
#               <dd class="displayData">
#                Pro Se
#               </dd>
#               <dt>
#                Bar Code
#               </dt>
#               <dd class="displayData">
#                PROPER
#               </dd>
#               <dt>
#                Address
#               </dt>
#               <dt>
#                Phone Number
#               </dt>
#               <dd class="displayData">
#               </dd>
#              </dl>
#             </div>
#            </div>
#            <div class="moreInfo ptyMore">
#             <a href="#" id="id1205" onclick="var wcall=wicketAjaxGet('../?x=8DatfxovrgUazXIMhwQe0uhC*1MgPseQVWNUIsIyxNbgG54Of7NPxK3AN2zDEuyKtyHlwEWlW0iuat9*qvhUmYHqYhMDWyaLPUCJr3K8t3zcCCawjaBf6VaRbJZ564nMnxDvHBSAYNB7FdRMeJ7GmGFO4zeYf-wQvR3HuA8XPlGqgVVMYuUCcA',function() { }.bind(this),function() { }.bind(this), function() {return Wicket.$('id1205') != null;}.bind(this));return !wcall;">
#              More Party Information
#             </a>
#            </div>
#            <div class="moreInfo">
#            </div>
#            <div class="moreInfo">
#            </div>
#            <div style="display:none;">
#             This is tooltip Text.  It should display nicely.
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="allInfoPanel" id="id1206">
#         <div class="subsection2 bgClr1" id="eventInfo">
#          <div class="subSectionHeader">
#           <h4>
#            <div>
#             Events
#            </div>
#           </h4>
#          </div>
#          <table class="tablesorter" id="id11f0" summary="Table displaying the events related to this case ordered chronologically.">
#           <thead>
#            <tr class="headers">
#             <th scope="col">
#              <span>
#               Date
#              </span>
#             </th>
#             <th scope="col">
#              <span>
#               Session
#              </span>
#             </th>
#             <th scope="col">
#              <span>
#               Locality
#              </span>
#             </th>
#             <th scope="col">
#              <span>
#               Location
#              </span>
#             </th>
#             <th scope="col">
#              <span>
#               Type
#              </span>
#             </th>
#             <th scope="col">
#              <span>
#               Result
#              </span>
#             </th>
#            </tr>
#           </thead>
#           <tfoot>
#           </tfoot>
#           <tbody>
#            <tr class="rowodd">
#             <td scope="row">
#              <span>
#               01/25/2001  09:00 AM
#              </span>
#             </td>
#             <td>
#              <span>
#               Lawrence Session
#              </span>
#             </td>
#             <td>
#              <span>
#              </span>
#             </td>
#             <td>
#              <span>
#               Northeast Housing Court
#              </span>
#             </td>
#             <td>
#              <span>
#               Trial
#              </span>
#             </td>
#             <td>
#              <span>
#              </span>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </div>
#        </div>
#        <div class="allInfoPanel" id="id1207">
#         <div class="subsection2 bgClr1 financialSection" id="docketInfo">
#          <div class="subSectionHeader">
#           <h4>
#            <div>
#             Docket Information
#            </div>
#           </h4>
#          </div>
#          <table class="tablesorter" id="id11f1">
#           <thead>
#            <tr class="headers">
#             <th scope="col">
#              <span>
#               Docket Date
#              </span>
#             </th>
#             <th scope="col">
#              <span>
#               Docket Text
#              </span>
#             </th>
#             <th scope="col">
#              <span>
#               File Ref Nbr.
#              </span>
#             </th>
#            </tr>
#           </thead>
#           <tfoot>
#           </tfoot>
#           <tbody>
#            <tr class="roweven">
#             <td scope="row">
#              01/09/2001
#             </td>
#             <td class="formattedText">
#              Converted from ECMS (07/13/2007)
#             </td>
#             <td>
#             </td>
#            </tr>
#            <tr class="rowodd">
#             <td scope="row">
#              01/09/2001
#             </td>
#             <td class="formattedText">
#              Summary Process, NTQ filed, 01-25-01
#             </td>
#             <td>
#              1
#             </td>
#            </tr>
#            <tr class="roweven">
#             <td scope="row">
#              01/25/2001
#             </td>
#             <td class="formattedText">
#              Default, pltf military &amp; R.10 affidavit
#             </td>
#             <td>
#              2
#             </td>
#            </tr>
#            <tr class="rowodd">
#             <td scope="row">
#              01/26/2001
#             </td>
#             <td class="formattedText">
#              Judgment by default in SP case entered
#             </td>
#             <td>
#              3
#             </td>
#            </tr>
#            <tr class="roweven">
#             <td scope="row">
#              01/26/2001
#             </td>
#             <td class="formattedText">
#              Judgement Type: JCV
# Judgement Date: 01/26/2001
# Judgement For: P 1  John Silverio
# Judgement Against: D 1  Phat Duong Au
# Judge: David D.  Kerman
# Interest Rate: 0.12
# Date Interest Begins: 01/09/2001
# Date Judgment Entered: 01/26/2001
# Single Damage Amount:        $1,570.00
# Prejudgment Interest: 8.77
# Punitive Damages:             $.00
# Court Ordered Attorney Fee:             $.00
# Filing Fee and Surcharge:             $.00
# Other Costs Paid To Court:           $86.00
# Costs Total:           $86.00
# Damges Total:        $1,664.77
# Execution Date: 02/06/2001
#             </td>
#             <td>
#             </td>
#            </tr>
#            <tr class="rowodd">
#             <td scope="row">
#              02/06/2001
#             </td>
#             <td class="formattedText">
#              Execution in SP case issued
#             </td>
#             <td>
#              4
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </div>
#        </div>
#        <div class="allInfoPanel" id="id1208">
#         <div class="subsection2 bgClr1" id="dispositionInfo">
#          <div class="subSectionHeader">
#           <h4>
#            <div>
#             Case Disposition
#            </div>
#           </h4>
#          </div>
#          <table class="tablesorter" id="id11f2" summary="Table displaying the dispositions on this case ordered chronologically.">
#           <thead>
#            <tr class="headers">
#             <th scope="col">
#              <span>
#               Disposition
#              </span>
#             </th>
#             <th scope="col">
#              <span>
#               Date
#              </span>
#             </th>
#            </tr>
#           </thead>
#           <tfoot>
#           </tfoot>
#           <tbody>
#            <tr class="rowodd">
#             <td scope="row">
#              Disposed
#             </td>
#             <td>
#              01/26/2001
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </div>
#        </div>
#        <div class="allInfoPanel">
#         <div class="subsection2 bgClr1 judgementsInfo">
#          <div class="subSectionHeader">
#           <h4>
#            <span>
#             Judgments
#            </span>
#           </h4>
#          </div>
#          <table class="tablesorter" id="id11f3" summary="Table displaying the Judgments on this case ordered chronologically.">
#           <thead>
#            <tr class="headers">
#             <th scope="col">
#              <span>
#               Date
#              </span>
#             </th>
#             <th scope="col">
#              <span>
#               Type
#              </span>
#             </th>
#             <th scope="col">
#              <span>
#               Method
#              </span>
#             </th>
#             <th scope="col">
#              <span>
#               For
#              </span>
#             </th>
#             <th scope="col">
#              <span>
#               Against
#              </span>
#             </th>
#            </tr>
#           </thead>
#           <tfoot>
#           </tfoot>
#           <tbody>
#            <tr class="rowodd">
#             <td>
#              <span>
#               01/26/2001
#              </span>
#             </td>
#             <td>
#              <span>
#               JCV
#              </span>
#             </td>
#             <td>
#              <span>
#               Finding
#              </span>
#             </td>
#             <td>
#              <span>
#               Silverio, John
#              </span>
#             </td>
#             <td>
#              <span>
#               Duong Au, Phat
#              </span>
#             </td>
#            </tr>
#           </tbody>
#          </table>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="ui-layout-south" style="display: block;">
#    <div id="footer">
#     <div id="footerLogo" title="eServices provided by CourtView Justice Solutions.">
#     </div>
#     <div id="footerContent">
#      <p>
#       Copyright © 2016 CourtView Justice Solutions, Inc.
#      </p>
#      <div class="versionId">
#       1.18.05
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="hidden" id="sessionLocaleLanguage">
#    EN-US
#   </div>
#   <div class="hidden" id="serverName">
#    xxx.xxx.xxx.xxx
#   </div>
#   <div class="hidden" id="sessionId">
#    yyyyyyyyyyyyyy
#   </div>
#   <div class="hidden" id="generationTime">
#    0000
#   </div>
#   <div class="hidden" id="generationSize">
#    0000
#   </div>
#   <div id="id11e5" style="display: none;">
#    <br/>
#    <br/>
#    <br/>
#    <center>
#     <img src="../resources/org.apache.wicket.ajax.AbstractDefaultAjaxBehavior/indicator.gif"/>
#    </center>
#   </div>
#   <script type="text/javascript">
#    $(document).ready(function() {
# 	var myLayout; // a var is required because this page utilizes: myLayout.allowOverflow() method
# 	window.cjsBrowserRenderEndTime = new Date();
# 	});
#   </script>
#   <script id="JavaScriptMarkupResponseLastScript" type="text/javascript">
#    <!--/*--><![CDATA[/*><!--*/
# window.cjsBrowserRenderEndTime = new Date();
# /*-->]]>*/
#   </script>
#  </body>
# </html>

# %% [markdown]
# # Find the defendants

# %%
# Find our defendants

for element in test.find_all(attrs = {"class": "ptyType"}):
    if "Defendant" in element.text:
        print("Defendant: ",element.previous_sibling.strip())
# Out:
# Defendant:  Duong Au, Phat

# %% [markdown]
# # Find the house address

# %%
# Find the property address
location = test.find_all(attrs = {"class": "additionalCaseInfoPanel"})
for element in location:
    data = [thing.get_text().strip() for thing in element.find_all("span") if thing.get_text() != ""]  

tuple(data)
# Out:
# ('Property Address', '279', '2nd Floor', 'Lawrence', 'MA', '01843')

# %% [markdown]
# # Find the court

# %%
for element in test.find_all("span"):
    if element.get_text().endswith("Court"):
        court = element.get_text()
        break
else:
    court = "Summary Proccess"

print(court)
# Out:
# Northeast Housing Court

# %% [markdown]
# # Putting it together:

# %% [markdown]
# Dependeng in if you're doing a test run or a real run, use an abbreviated piece of the data.  I meant to bring the 24MB condensed data with me, but unfortunately left that on my drive in Boston, so I'm going to work with a small subset.

# %%
# %%time

collection = []

begin = 125000
end = 125100

for i,file in enumerate(os.listdir()[begin:end]):
    
    # only open html files
    if file.endswith(".html"):

        with open(file,"r") as f:
            source = f.read()
            soup = bs4.BeautifulSoup(source,"html.parser")

            # a list for tracking the defendants
            defs = []
            
            # store all the defendants
            for element in soup.find_all(attrs = {"class": "ptyType"}):
                if "Defendant" in element.text:
                    defs.append(element.previous_sibling.strip())

            # Find the property address
            location_data = soup.find_all(attrs = {"class": "additionalCaseInfoPanel"})
            for element in location_data:
                
                # extract the lines of the address
                location = tuple([thing.get_text().strip() for thing in element.find_all("span") if thing.get_text() != ""]  )

            # find the court district if available
            for element in soup.find_all("span"):
                if element.get_text().endswith("Court"):
                    court = element.get_text()
                    break
            # list "summary process if court not formally named"
            else:
                court = "Summary Process"

        # at the end, store the results
        to_add = [(i, defendant, location, court) for defendant in defs]
        collection.extend(to_add)
# Out:
# CPU times: user 6.41 s, sys: 173 ms, total: 6.58 s
# Wall time: 7.06 s

# %% [markdown]
# 7 seconds for 100 data points on my macbook air.

# %%
collection
# Out:
# [(0,
#   'Mercurio, Danniel',
#   ('Property Address',
#    '73',
#    'Riverlin',
#    'Street',
#    '2B',
#    'Millbury',
#    'MA',
#    '01527'),
#   'Worcester Housing Court'),
#  (0,
#   'Manna, Michael',
#   ('Property Address',
#    '73',
#    'Riverlin',
#    'Street',
#    '2B',
#    'Millbury',
#    'MA',
#    '01527'),
#   'Worcester Housing Court'),
#  (1,
#   'Grandinetti, Anthony',
#   ('Property Address',
#    '73',
#    'Riverlin',
#    'Street',
#    '2A',
#    'Millbury',
#    'MA',
#    '01527'),
#   'Worcester Housing Court'),
#  (2,
#   'Walker, Ricky Allen',
#   ('Property Address',
#    '66',
#    'Laurel',
#    'Street',
#    '2nd floor',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (2,
#   'Walker, Alfreda Frazier',
#   ('Property Address',
#    '66',
#    'Laurel',
#    'Street',
#    '2nd floor',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (2,
#   'Frazier, Shemeka',
#   ('Property Address',
#    '66',
#    'Laurel',
#    'Street',
#    '2nd floor',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (3,
#   'Boateng, Ibriham',
#   ('Property Address', '169', 'Mower', 'Street', 'Worcester', 'MA', '01602'),
#   'Worcester Housing Court'),
#  (3,
#   'Boateng, Vida',
#   ('Property Address', '169', 'Mower', 'Street', 'Worcester', 'MA', '01602'),
#   'Worcester Housing Court'),
#  (4,
#   'Day, Jordan',
#   ('Property Address',
#    '32',
#    'Blossom',
#    'Street',
#    '3rd floor',
#    'Leominster',
#    'MA',
#    '01453'),
#   'Summary Process'),
#  (4,
#   'Kidder, Samantha',
#   ('Property Address',
#    '32',
#    'Blossom',
#    'Street',
#    '3rd floor',
#    'Leominster',
#    'MA',
#    '01453'),
#   'Summary Process'),
#  (5,
#   'Beck, Sonnie',
#   ('Property Address',
#    '35',
#    'Graham',
#    'Street',
#    '2',
#    'Gardner',
#    'MA',
#    '01440'),
#   'Summary Process'),
#  (6,
#   'Jackson, Roxanne',
#   ('Property Address',
#    '44',
#    'Whipple',
#    'Street',
#    '2',
#    'Worcester',
#    'MA',
#    '01607'),
#   'Worcester Housing Court'),
#  (7,
#   'Dodge, Kim',
#   ('Property Address', '420', 'Cutler', 'Road', 'Barre', 'MA', '01005'),
#   'Worcester Housing Court'),
#  (8,
#   'Iglesias, Libia',
#   ('Property Address',
#    '159',
#    'Cohasset',
#    'Street',
#    '1',
#    'Worcester',
#    'MA',
#    '01604'),
#   'Worcester Housing Court'),
#  (9,
#   'Hall, Mary Jo',
#   ('Property Address',
#    '20',
#    'Helen',
#    'Drive',
#    '1',
#    'West Boylston',
#    'MA',
#    '01583'),
#   'Worcester Housing Court'),
#  (10,
#   'LaForest, Rebecca',
#   ('Property Address',
#    '76',
#    'Whipple',
#    'Street',
#    '2',
#    'Worcester',
#    'MA',
#    '01607'),
#   'Worcester Housing Court'),
#  (11,
#   'Fontaine, Jason',
#   ('Property Address',
#    '14',
#    'Claremont',
#    'Street',
#    '3',
#    'Worcester',
#    'MA',
#    '01610'),
#   'Worcester Housing Court'),
#  (12,
#   'Marcotte, Stacey',
#   ('Property Address',
#    '27',
#    'Catherine',
#    'Street',
#    '14',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (13,
#   'Hutchinson, Gary',
#   ('Property Address',
#    '109',
#    'High',
#    'Street',
#    '2nd fl.',
#    'Southbridge',
#    'MA',
#    '01550'),
#   'Summary Process'),
#  (13,
#   'Chabot, Jessilyn',
#   ('Property Address',
#    '109',
#    'High',
#    'Street',
#    '2nd fl.',
#    'Southbridge',
#    'MA',
#    '01550'),
#   'Summary Process'),
#  (14,
#   'Olewinska, Ewa',
#   ('Property Address', '11', 'Catalpa', 'Circle', 'Worcester', 'MA', '01603'),
#   'Worcester Housing Court'),
#  (15,
#   'Birch, David',
#   ('Property Address', '36', 'Thomas', 'Street', 'Southbridge', 'MA', '01550'),
#   'Summary Process'),
#  (16,
#   'Gractus, Mildred',
#   ('Property Address',
#    '116',
#    'River',
#    'Street',
#    '1',
#    'Southbridge',
#    'MA',
#    '01550'),
#   'Summary Process'),
#  (16,
#   'Colon, David',
#   ('Property Address',
#    '116',
#    'River',
#    'Street',
#    '1',
#    'Southbridge',
#    'MA',
#    '01550'),
#   'Summary Process'),
#  (17,
#   'Seraphin, Scott',
#   ('Property Address', '3', 'East', 'Main', '3-R', 'Webster', 'MA', '01570'),
#   'Summary Process'),
#  (18,
#   'Secrest, Tracy',
#   ('Property Address',
#    '161',
#    'West',
#    'Square',
#    '1-L',
#    'Leominster',
#    'MA',
#    '01453'),
#   'Summary Process'),
#  (19,
#   'Morse, Michelle',
#   ('Property Address',
#    '776',
#    'Main',
#    'Street',
#    '6',
#    'Worcester',
#    'MA',
#    '01610'),
#   'Worcester Housing Court'),
#  (19,
#   'Soldi, Dale',
#   ('Property Address',
#    '776',
#    'Main',
#    'Street',
#    '6',
#    'Worcester',
#    'MA',
#    '01610'),
#   'Worcester Housing Court'),
#  (20,
#   'Sotto, Rodolfo',
#   ('Property Address', '152', 'Lovell', 'Street', 'Worcester', 'MA', '01609'),
#   'Worcester Housing Court'),
#  (20,
#   'Shackett, Beth',
#   ('Property Address', '152', 'Lovell', 'Street', 'Worcester', 'MA', '01609'),
#   'Worcester Housing Court'),
#  (21,
#   'Morales, Leo',
#   ('Property Address',
#    '342',
#    'Lincoln',
#    'Street',
#    '419',
#    'Marlborough',
#    'MA',
#    '01752'),
#   'Summary Process'),
#  (22,
#   'Bartlett, Denise',
#   ('Property Address',
#    '3',
#    'Congress',
#    'Place',
#    '3rd Floor',
#    'Fitchburg',
#    'MA',
#    '01420'),
#   'Summary Process'),
#  (22,
#   'Bartlett, Robert',
#   ('Property Address',
#    '3',
#    'Congress',
#    'Place',
#    '3rd Floor',
#    'Fitchburg',
#    'MA',
#    '01420'),
#   'Summary Process'),
#  (23,
#   'Billinger, Pricilla',
#   ('Property Address',
#    '41',
#    'Stoneland',
#    'Road',
#    'Bsmt',
#    'Worcester',
#    'MA',
#    '01603'),
#   'Worcester Housing Court'),
#  (24,
#   'McKearney, Adam',
#   ('Property Address',
#    '25',
#    'Champlain',
#    'Avenue',
#    '2L',
#    'Blackstone',
#    'MA',
#    '01504'),
#   'Summary Process'),
#  (25,
#   'Burdett, Elisha',
#   ('Property Address', '6132', 'Arbor', 'Drive', 'Shrewsbury', 'MA', '01545'),
#   'Worcester Housing Court'),
#  (26,
#   'Soto, Rosa',
#   ('Property Address', '3211', 'Arbor', 'Drive', 'Shrewsbury', 'MA', '01545'),
#   'Worcester Housing Court'),
#  (27,
#   'Salguero, Jose',
#   ('Property Address',
#    '103',
#    'Howe',
#    'Street',
#    '1st Floor',
#    'Marlborough',
#    'MA',
#    '01752'),
#   'Summary Process'),
#  (27,
#   'Salomne, Jennifer',
#   ('Property Address',
#    '103',
#    'Howe',
#    'Street',
#    '1st Floor',
#    'Marlborough',
#    'MA',
#    '01752'),
#   'Summary Process'),
#  (28,
#   'Baez, Ramon',
#   ('Property Address',
#    '1',
#    'Varney',
#    'Street',
#    '1L',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (28,
#   'Torres, Dayanara',
#   ('Property Address',
#    '1',
#    'Varney',
#    'Street',
#    '1L',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (29,
#   'Martinez, Carmelo',
#   ('Property Address',
#    '37',
#    'Endicott',
#    'Street',
#    'Apt. 3',
#    'Worcester',
#    'MA',
#    '01610'),
#   'Worcester Housing Court'),
#  (29,
#   'Correa, Joey',
#   ('Property Address',
#    '37',
#    'Endicott',
#    'Street',
#    'Apt. 3',
#    'Worcester',
#    'MA',
#    '01610'),
#   'Worcester Housing Court'),
#  (29,
#   'Reyes, H',
#   ('Property Address',
#    '37',
#    'Endicott',
#    'Street',
#    'Apt. 3',
#    'Worcester',
#    'MA',
#    '01610'),
#   'Worcester Housing Court'),
#  (30,
#   'Nguyen, Trung',
#   ('Property Address',
#    '37',
#    'Endicott',
#    'Street',
#    'Apt. 2',
#    'Worcester',
#    'MA',
#    '01610'),
#   'Worcester Housing Court'),
#  (31,
#   'Szklarz, Caitlin',
#   ('Property Address',
#    '522',
#    'Grafton',
#    'Street',
#    '3',
#    'Worcester',
#    'MA',
#    '01604'),
#   'Worcester Housing Court'),
#  (32,
#   'Szklarz, Jennifer',
#   ('Property Address',
#    '522',
#    'Grafton',
#    'Street',
#    '2',
#    'Worcester',
#    'MA',
#    '01604'),
#   'Worcester Housing Court'),
#  (33,
#   'Berger, Pamela',
#   ('Property Address',
#    '124',
#    'Manca',
#    'Drive',
#    '2A',
#    'Gardner',
#    'MA',
#    '01440'),
#   'Summary Process'),
#  (33,
#   'Mason, Corey',
#   ('Property Address',
#    '124',
#    'Manca',
#    'Drive',
#    '2A',
#    'Gardner',
#    'MA',
#    '01440'),
#   'Summary Process'),
#  (34,
#   'Delaney, Megan',
#   ('Property Address', '94', 'Hemlock', 'Drive', 'Gardner', 'MA', '01440'),
#   'Summary Process'),
#  (34,
#   'Casteel, II, David M',
#   ('Property Address', '94', 'Hemlock', 'Drive', 'Gardner', 'MA', '01440'),
#   'Summary Process'),
#  (35,
#   'Silva, Stacey',
#   ('Property Address',
#    '172',
#    'Manca',
#    'Drive',
#    '204',
#    'Gardner',
#    'MA',
#    '01440'),
#   'Summary Process'),
#  (36,
#   'Demis, Panteles',
#   ('Property Address',
#    '240',
#    'Belmont',
#    'Street',
#    '1-315',
#    'Worcester',
#    'MA',
#    '01604'),
#   'Worcester Housing Court'),
#  (37,
#   "O'Brien, Jay",
#   ('Property Address',
#    '244',
#    'Belmont',
#    'Street',
#    '2--103',
#    'Worcester',
#    'MA',
#    '01604'),
#   'Worcester Housing Court'),
#  (38,
#   'Fullerton, David',
#   ('Property Address',
#    '100',
#    'Tower',
#    'Street',
#    '305',
#    'Hudson',
#    'MA',
#    '01749'),
#   'Summary Process'),
#  (39,
#   'Gonzalez, Vivian',
#   ('Property Address',
#    '173',
#    'Country Club',
#    'Boulevard',
#    '504',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (40,
#   'Quinn, James',
#   ('Property Address',
#    '161',
#    'Country Club',
#    'Boulevard',
#    '417',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (40,
#   'Quinn, Kathryn',
#   ('Property Address',
#    '161',
#    'Country Club',
#    'Boulevard',
#    '417',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (41,
#   'McLune, Javon',
#   ('Property Address',
#    '149',
#    'Country Club',
#    'Boulevard',
#    '524',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (42,
#   'Nival, Nector',
#   ('Property Address',
#    '139',
#    'Country Club',
#    'Boulevard',
#    '530',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (43,
#   'Valentin, Elizabeth',
#   ('Property Address',
#    '132',
#    'Country Club',
#    'Boulevard',
#    '403',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (44,
#   'Williams, Melissa',
#   ('Property Address',
#    '112',
#    'Country Club',
#    'Boulevard',
#    '288',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (45,
#   'Hawkes, Melissa',
#   ('Property Address',
#    '112',
#    'Country Club',
#    'Boulevard',
#    '285',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (46,
#   'Ofori-Atta, Michael',
#   ('Property Address',
#    '111',
#    'Country Club',
#    'Boulevard',
#    '611',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (47,
#   'Laurent, Fedna',
#   ('Property Address',
#    '99',
#    'Country Club',
#    'Boulevard',
#    '94',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (48,
#   'Ramos, Luis',
#   ('Property Address',
#    '98',
#    'Country Club',
#    'Boulevard',
#    '310',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (48,
#   'Cintron, Maria',
#   ('Property Address',
#    '98',
#    'Country Club',
#    'Boulevard',
#    '310',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (49,
#   'Quinones, Orlando',
#   ('Property Address',
#    '94',
#    'Country Club',
#    'Boulevard',
#    '274',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (50,
#   'Danso, Clifford',
#   ('Property Address',
#    '91',
#    'Country Club',
#    'Boulevard',
#    '145',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (51,
#   'Lamin, Marie',
#   ('Property Address',
#    '90',
#    'Country Club',
#    'Boulevard',
#    '257',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (51,
#   'Glenn, Philip',
#   ('Property Address',
#    '90',
#    'Country Club',
#    'Boulevard',
#    '257',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (51,
#   'Bomah, Ajaratu',
#   ('Property Address',
#    '90',
#    'Country Club',
#    'Boulevard',
#    '257',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (51,
#   'Glenn, Jermie',
#   ('Property Address',
#    '90',
#    'Country Club',
#    'Boulevard',
#    '257',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (52,
#   'Matias, Alejandro',
#   ('Property Address',
#    '74',
#    'Country Club',
#    'Boulevard',
#    '236',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (52,
#   'Matias, Nancy',
#   ('Property Address',
#    '74',
#    'Country Club',
#    'Boulevard',
#    '236',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (53,
#   'Reyes, Guanina',
#   ('Property Address',
#    '40',
#    'Pleasant Valley',
#    'Drive',
#    '12',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (54,
#   'Agyeman-Wilder, Nana A.',
#   ('Property Address', '19', 'Oriental', 'Street', 'Worcester', 'MA', '01605'),
#   'Worcester Housing Court'),
#  (55,
#   'Bergeron, Bill',
#   ('Property Address',
#    '98',
#    'Canterbury',
#    'Street',
#    '2nd Floor',
#    'Worcester',
#    'MA',
#    '01610'),
#   'Worcester Housing Court'),
#  (56,
#   'McKinnon, Kathleen',
#   ('Property Address',
#    '7',
#    'Wawecus',
#    'Road',
#    '1',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (56,
#   'McKinnon, James',
#   ('Property Address',
#    '7',
#    'Wawecus',
#    'Road',
#    '1',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (57,
#   'Merchant, Russell A',
#   ('Property Address',
#    '707',
#    'Main',
#    'Street',
#    '7',
#    'Worcester',
#    'MA',
#    '01610'),
#   'Worcester Housing Court'),
#  (58,
#   'Leone, Jaclyn',
#   ('Property Address',
#    '148',
#    'Lovell',
#    'Street',
#    '3L',
#    'Worcester',
#    'MA',
#    '01603'),
#   'Worcester Housing Court'),
#  (58,
#   'Hunt, Andrew',
#   ('Property Address',
#    '148',
#    'Lovell',
#    'Street',
#    '3L',
#    'Worcester',
#    'MA',
#    '01603'),
#   'Worcester Housing Court'),
#  (59,
#   'Mendez, Belmira',
#   ('Property Address',
#    '634',
#    'Grafton',
#    'Street',
#    '3',
#    'Worcester',
#    'MA',
#    '01604'),
#   'Worcester Housing Court'),
#  (59,
#   'Saffo, Franklin',
#   ('Property Address',
#    '634',
#    'Grafton',
#    'Street',
#    '3',
#    'Worcester',
#    'MA',
#    '01604'),
#   'Worcester Housing Court'),
#  (60,
#   'Rodriguez, Lisbed',
#   ('Property Address',
#    '61',
#    'East',
#    'Central',
#    'Street',
#    '3',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (61,
#   'Forgette, Harold',
#   ('Property Address',
#    '21',
#    'Oread',
#    'Street',
#    'Room 7',
#    'Worcester',
#    'MA',
#    '01608'),
#   'Worcester Housing Court'),
#  (62,
#   'Melinski, William',
#   ('Property Address',
#    '417',
#    'Blackstone',
#    'Street',
#    'Uxbridge',
#    'MA',
#    '01569'),
#   'Summary Process'),
#  (62,
#   'Melinski, Samantha',
#   ('Property Address',
#    '417',
#    'Blackstone',
#    'Street',
#    'Uxbridge',
#    'MA',
#    '01569'),
#   'Summary Process'),
#  (62,
#   'Pontremoli, Robert',
#   ('Property Address',
#    '417',
#    'Blackstone',
#    'Street',
#    'Uxbridge',
#    'MA',
#    '01569'),
#   'Summary Process'),
#  (63,
#   'Peredes, Roberto',
#   ('Property Address',
#    '102',
#    'Arthur',
#    'Street',
#    '1st fl.',
#    'Worcester',
#    'MA',
#    '01604'),
#   'Worcester Housing Court'),
#  (63,
#   'Rojas, Ms',
#   ('Property Address',
#    '102',
#    'Arthur',
#    'Street',
#    '1st fl.',
#    'Worcester',
#    'MA',
#    '01604'),
#   'Worcester Housing Court'),
#  (64,
#   'Martin, George',
#   ('Property Address',
#    '384',
#    'Sunderland',
#    'Road',
#    '20',
#    'Worcester',
#    'MA',
#    '01604'),
#   'Worcester Housing Court'),
#  (64,
#   'Collins, Prince',
#   ('Property Address',
#    '384',
#    'Sunderland',
#    'Road',
#    '20',
#    'Worcester',
#    'MA',
#    '01604'),
#   'Worcester Housing Court'),
#  (64,
#   'Essilfie, Sophia',
#   ('Property Address',
#    '384',
#    'Sunderland',
#    'Road',
#    '20',
#    'Worcester',
#    'MA',
#    '01604'),
#   'Worcester Housing Court'),
#  (65,
#   'Harp, Vanessa',
#   ('Property Address', '27', 'Freedom', 'Way', 'Worcester', 'MA', '01605'),
#   'Worcester Housing Court'),
#  (66,
#   'Santana, Saul',
#   ('Property Address',
#    '1050',
#    'Main',
#    'Street',
#    '1203',
#    'Worcester',
#    'MA',
#    '01603'),
#   'Worcester Housing Court'),
#  (67,
#   'Roman, Maria',
#   ('Property Address',
#    '204',
#    'Beacon',
#    'Street',
#    'B',
#    'Worcester',
#    'MA',
#    '01610'),
#   'Worcester Housing Court'),
#  (67,
#   'Roman, Aleesha',
#   ('Property Address',
#    '204',
#    'Beacon',
#    'Street',
#    'B',
#    'Worcester',
#    'MA',
#    '01610'),
#   'Worcester Housing Court'),
#  (68,
#   'Stowell, Darlene R',
#   ('Property Address',
#    '69',
#    'Worcester',
#    'Street',
#    '1',
#    'Southbridge',
#    'MA',
#    '01550'),
#   'Summary Process'),
#  (69,
#   'Cote, Robert',
#   ('Property Address',
#    '28',
#    'Maple',
#    'Street',
#    'C',
#    'Baldwinville',
#    'MA',
#    '01436'),
#   'Summary Process'),
#  (69,
#   'Tylenda, Rachel',
#   ('Property Address',
#    '28',
#    'Maple',
#    'Street',
#    'C',
#    'Baldwinville',
#    'MA',
#    '01436'),
#   'Summary Process'),
#  (70,
#   'Norton, Kerry',
#   ('Property Address', '23', 'Hartford', 'Street', 'Fitchburg', 'MA', '01420'),
#   'Summary Process'),
#  (71,
#   'Rodriguez-Valera, Natasha',
#   ('Property Address', '25', 'Hartford', 'Street', 'Fitchburg', 'MA', '01420'),
#   'Worcester Housing Court'),
#  (72,
#   'Nygard, Shawna',
#   ('Property Address',
#    '265',
#    'Cambridge',
#    'Street',
#    '1',
#    'Worcester',
#    'MA',
#    '01603'),
#   'Worcester Housing Court'),
#  (73,
#   'Dellacononica, Richard',
#   ('Property Address',
#    '169',
#    'Medway',
#    'Road',
#    '12',
#    'Milford',
#    'MA',
#    '01757'),
#   'Summary Process'),
#  (73,
#   'Yung, Elena',
#   ('Property Address',
#    '169',
#    'Medway',
#    'Road',
#    '12',
#    'Milford',
#    'MA',
#    '01757'),
#   'Summary Process'),
#  (74,
#   'Camerra, Deborah',
#   ('Property Address',
#    '59',
#    'Trenton',
#    'Street',
#    '2',
#    'Worcester',
#    'MA',
#    '01604'),
#   'Worcester Housing Court'),
#  (74,
#   'Bilodeau, Melissa',
#   ('Property Address',
#    '59',
#    'Trenton',
#    'Street',
#    '2',
#    'Worcester',
#    'MA',
#    '01604'),
#   'Worcester Housing Court'),
#  (74,
#   'Godfrey, Raymond',
#   ('Property Address',
#    '59',
#    'Trenton',
#    'Street',
#    '2',
#    'Worcester',
#    'MA',
#    '01604'),
#   'Worcester Housing Court'),
#  (75,
#   'Rivera, Maria',
#   ('Property Address', '1008-1', 'Main', 'Street', 'Worcester', 'MA', '01603'),
#   'Worcester Housing Court'),
#  (75,
#   'Colon, Luz',
#   ('Property Address', '1008-1', 'Main', 'Street', 'Worcester', 'MA', '01603'),
#   'Worcester Housing Court'),
#  (76,
#   'Encarnacion, Julio',
#   ('Property Address', '2A-4', 'Marble', 'Street', 'Worcester', 'MA', '01603'),
#   'Worcester Housing Court'),
#  (76,
#   'Gutierez, Joana',
#   ('Property Address', '2A-4', 'Marble', 'Street', 'Worcester', 'MA', '01603'),
#   'Worcester Housing Court'),
#  (77,
#   'Mensah, Monique',
#   ('Property Address',
#    '22',
#    'Carleton',
#    'Street',
#    '1R',
#    'Worcester',
#    'MA',
#    '01603'),
#   'Worcester Housing Court'),
#  (78,
#   'Rosado, Madeline',
#   ('Property Address', '1006-6', 'Main', 'Street', 'Worcester', 'MA', '01603'),
#   'Worcester Housing Court'),
#  (79,
#   'Harden, Ronald',
#   ('Property Address', '17', 'Enid', 'Street', 'Worcester', 'MA', '01604'),
#   'Worcester Housing Court'),
#  (79,
#   'Harden, Garrett',
#   ('Property Address', '17', 'Enid', 'Street', 'Worcester', 'MA', '01604'),
#   'Worcester Housing Court'),
#  (80,
#   'McBride, Amy',
#   ('Property Address', '240', 'Waterford', 'Street', 'Gardner', 'MA', '01440'),
#   'Summary Process'),
#  (81,
#   'Russin, Richard',
#   ('Property Address', '151', 'Oak', 'Street', '1', 'Clinton', 'MA', '01510'),
#   'Worcester Housing Court'),
#  (82,
#   'Vargas, Javier',
#   ('Property Address',
#    '5',
#    'Allen',
#    'Place',
#    '3-C',
#    'Fitchburg',
#    'MA',
#    '01420'),
#   'Summary Process'),
#  (82,
#   'Ramirez, Angel',
#   ('Property Address',
#    '5',
#    'Allen',
#    'Place',
#    '3-C',
#    'Fitchburg',
#    'MA',
#    '01420'),
#   'Summary Process'),
#  (82,
#   'Valente, Angel',
#   ('Property Address',
#    '5',
#    'Allen',
#    'Place',
#    '3-C',
#    'Fitchburg',
#    'MA',
#    '01420'),
#   'Summary Process'),
#  (82,
#   'Daniels, Julie',
#   ('Property Address',
#    '5',
#    'Allen',
#    'Place',
#    '3-C',
#    'Fitchburg',
#    'MA',
#    '01420'),
#   'Summary Process'),
#  (83,
#   'Mercado, Jonathan',
#   ('Property Address',
#    '86',
#    'Austin',
#    'Street',
#    '619',
#    'Worcester',
#    'MA',
#    '01609'),
#   'Worcester Housing Court'),
#  (84,
#   'Devescovi, John',
#   ('Property Address',
#    '600',
#    'Main',
#    'Street',
#    '1301',
#    'Worcester',
#    'MA',
#    '01608'),
#   'Worcester Housing Court'),
#  (85,
#   'Casserly, Deborah',
#   ('Property Address',
#    '773',
#    'Pleasant',
#    'Street',
#    '5',
#    'Worcester',
#    'MA',
#    '01602'),
#   'Worcester Housing Court'),
#  (85,
#   'Smith, Charlie',
#   ('Property Address',
#    '773',
#    'Pleasant',
#    'Street',
#    '5',
#    'Worcester',
#    'MA',
#    '01602'),
#   'Worcester Housing Court'),
#  (86,
#   'Powers, Robin',
#   ('Property Address', '9', 'Mystic', 'Street', 'Worcester', 'MA', '01607'),
#   'Worcester Housing Court'),
#  (87,
#   'Rivera, Tina',
#   ('Property Address',
#    '25',
#    'Suffield',
#    'Street',
#    '2L',
#    'Worcester',
#    'MA',
#    '01610'),
#   'Worcester Housing Court'),
#  (87,
#   'Santos, Mario',
#   ('Property Address',
#    '25',
#    'Suffield',
#    'Street',
#    '2L',
#    'Worcester',
#    'MA',
#    '01610'),
#   'Worcester Housing Court'),
#  (88,
#   'Johnson, Vanessa',
#   ('Property Address',
#    '61',
#    'Chatham',
#    'Street',
#    '1',
#    'Worcester',
#    'MA',
#    '01609'),
#   'Worcester Housing Court'),
#  (89,
#   'Colon, Jose M',
#   ('Property Address',
#    '129',
#    'High',
#    'Street',
#    '3rd floor',
#    'Fitchburg',
#    'MA',
#    '01420'),
#   'Summary Process'),
#  (89,
#   'Guzman, Josselyn',
#   ('Property Address',
#    '129',
#    'High',
#    'Street',
#    '3rd floor',
#    'Fitchburg',
#    'MA',
#    '01420'),
#   'Summary Process'),
#  (90,
#   'Gardner, Whitney',
#   ('Property Address', '76', 'Baker', 'Street', 'Gardner', 'MA', '01440'),
#   'Summary Process'),
#  (90,
#   'Richard, Tyler',
#   ('Property Address', '76', 'Baker', 'Street', 'Gardner', 'MA', '01440'),
#   'Summary Process'),
#  (91,
#   'Perrin, Rebekah',
#   ('Property Address', '804', 'Main', 'Street', 'A', 'Warren', 'MA', '01083'),
#   'Worcester Housing Court'),
#  (92,
#   'Amyot, Kimberly',
#   ('Property Address', '7', 'Ames', 'Street', '1', 'Worcester', 'MA', '01610'),
#   'Worcester Housing Court'),
#  (92,
#   'Jakubiak, Bryan',
#   ('Property Address', '7', 'Ames', 'Street', '1', 'Worcester', 'MA', '01610'),
#   'Worcester Housing Court'),
#  (93,
#   'Stickles, Matthew',
#   ('Property Address',
#    '14',
#    'Derby',
#    'Street',
#    '3',
#    'Worcester',
#    'MA',
#    '01604'),
#   'Worcester Housing Court'),
#  (94,
#   'Colby, Steven',
#   ('Property Address', '1', 'Pitt', 'Street', '3', 'Worcester', 'MA', '01610'),
#   'Worcester Housing Court'),
#  (94,
#   'Hill, Karen',
#   ('Property Address', '1', 'Pitt', 'Street', '3', 'Worcester', 'MA', '01610'),
#   'Worcester Housing Court'),
#  (95,
#   'Larson, Michael',
#   ('Property Address',
#    '94',
#    'Woodland',
#    'Street',
#    '1 left',
#    'Worcester',
#    'MA',
#    '01610'),
#   'Worcester Housing Court'),
#  (96,
#   'Morales, Marisol',
#   ('Property Address',
#    '7',
#    'Sturgis',
#    'Street',
#    '3',
#    'Worcester',
#    'MA',
#    '01605'),
#   'Worcester Housing Court'),
#  (97,
#   'Addabor, Nana',
#   ('Property Address',
#    '50',
#    'Franklin',
#    'Street',
#    '8Q',
#    'Worcester',
#    'MA',
#    '01608'),
#   'Worcester Housing Court'),
#  (98,
#   'Carter, Daniel',
#   ('Property Address',
#    '50',
#    'Franklin',
#    'Street',
#    '6V',
#    'Worcester',
#    'MA',
#    '01608'),
#   'Worcester Housing Court'),
#  (98,
#   'Martello, Alyssa',
#   ('Property Address',
#    '50',
#    'Franklin',
#    'Street',
#    '6V',
#    'Worcester',
#    'MA',
#    '01608'),
#   'Worcester Housing Court'),
#  (99,
#   'Reeves, Wynona',
#   ('Property Address',
#    '50',
#    'Franklin',
#    'Street',
#    '70',
#    'Worcester',
#    'MA',
#    '01608'),
#   'Worcester Housing Court')]

# %% [markdown]
# Note, late in the data set, we have proper addresses.  Early in the data set, we have street numbers and apartment numbers, but not full addresses.

# %% [markdown]
# Something I'm curious about: how many uniuqe addresses do we have.  The address lookup for census geocoding is slow.  So we should store any data we have along the way so we don't need to find it again.
#
# Keep a dictionary with street addresses, and match them with census tracts.

# %%
# How many unique addresses in 100:
addresses = [x[2][1:] for x in collection]

# %%
unique_addresses = defaultdict(int)
for x in addresses:
    unique_addresses[x] += 1

len(unique_addresses.keys())
# Out:
# 100

# %% [markdown]
# Not going to see a huge reduction in lookups with 100 addresses, but maybe with thousands?

# %% [markdown]
# # How much data do we have to process?

# %%
# If we process all the data:
len(os.listdir())
# Out:
# 130409

# %% [markdown]
# # Run this on the full data

# %%
# %%time

collection = []

for i,file in enumerate(os.listdir()):
    
    # only open html files
    if file.endswith(".html"):

        with open(file,"r") as f:
            source = f.read()
            soup = bs4.BeautifulSoup(source,"html.parser")

            # a list for tracking the defendants
            defs = []
            
            # store all the defendants
            for element in soup.find_all(attrs = {"class": "ptyType"}):
                if "Defendant" in element.text:
                    defs.append(element.previous_sibling.strip())

            # Find the property address
            location_data = soup.find_all(attrs = {"class": "additionalCaseInfoPanel"})
            for element in location_data:
                
                # extract the lines of the address
                location = tuple([thing.get_text().strip() for thing in element.find_all("span") if thing.get_text() != ""]  )

            # find the court district if available
            for element in soup.find_all("span"):
                if element.get_text().endswith("Court"):
                    court = element.get_text()
                    break
            # list "summary process if court not formally named"
            else:
                court = "Summary Process"

        # at the end, store the results
        to_add = [(i, defendant, location, court) for defendant in defs]
        collection.extend(to_add)
        
        
        if i %1000 == 0:
            print(i)
            
# Started at 1:38 PM.  Should finish around 2:10
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# Wall time: 49min 23s

# %% [markdown]
# ## Lesson learned
#
# If I process all the data in one large list, I see a huge hit on run time.  I should have split this up over multiple lists, and then combined them, or simply read them in chunks into a data frame.

# %%
len(collection)
# Out:
# 169629

# %% [markdown]
# Expected that we should have mor ethan 130k entries as lots of residences will have multiple tenants.  Kinda surprised there weren't more people named on more eviction records.

# %%
collection[-10:]
# Out:
# [(130402,
#   'Mason, Tracey',
#   ('Property Address',
#    '54',
#    'Greendale',
#    'Road',
#    '2L',
#    'Mattapan',
#    'MA',
#    '02126'),
#   'Summary Process'),
#  (130403,
#   'Monteiro, Lanier',
#   ('Property Address',
#    '97',
#    'Devon',
#    'Street',
#    '2',
#    'Dorchester',
#    'MA',
#    '02121'),
#   'Summary Process'),
#  (130404,
#   'Castiglioni, Jillian',
#   ('Property Address', '25', 'Park', 'Street', 'Blackstone', 'MA', '01504'),
#   'Worcester Housing Court'),
#  (130404,
#   'Beane, Carl',
#   ('Property Address', '25', 'Park', 'Street', 'Blackstone', 'MA', '01504'),
#   'Worcester Housing Court'),
#  (130405,
#   'Council, Letica',
#   ('Property Address',
#    '1301',
#    'Main',
#    'Street',
#    '2',
#    'Fitchburg',
#    'MA',
#    '01420'),
#   'Summary Process'),
#  (130406,
#   'English, Gloria',
#   ('Property Address', '251', 'Tacoma', 'Street', 'Worcester', 'MA', '01605'),
#   'Worcester Housing Court'),
#  (130406,
#   'Mangabang, David',
#   ('Property Address', '251', 'Tacoma', 'Street', 'Worcester', 'MA', '01605'),
#   'Worcester Housing Court'),
#  (130407,
#   'Rodrigues, Jasmine',
#   ('Property Address',
#    '135',
#    'West',
#    'Main',
#    'Street',
#    'Unit 6',
#    'Marlborough',
#    'MA',
#    '01752'),
#   'Summary Process'),
#  (130407,
#   'Ruby, Steven Anthony',
#   ('Property Address',
#    '135',
#    'West',
#    'Main',
#    'Street',
#    'Unit 6',
#    'Marlborough',
#    'MA',
#    '01752'),
#   'Summary Process'),
#  (130408,
#   'Clyde, Tamarah',
#   ('Property Address',
#    '62',
#    'Goddard',
#    'Street',
#    '2',
#    'Lunenburg',
#    'MA',
#    '01462'),
#   'Summary Process')]

# %%
import pickle as pkl

# %%
with open("compressed_records.pickle","wb") as f:
    pickle.dump(collection,f)

# %% [markdown]
# That should have pickled our data.  Let's test that we saved it by reloading it:

# %%
with open("compressed_records.pickle","rb") as f:
    new_collection = pickle.load(f)

len(new_collection)
# Out:
# 169629

# %%
import sys

# %%
sys.getsizeof(new_collection)
# Out:
# 1386112

# %%
new_collection[-10:]
# Out:
# [(130402,
#   'Mason, Tracey',
#   ('Property Address',
#    '54',
#    'Greendale',
#    'Road',
#    '2L',
#    'Mattapan',
#    'MA',
#    '02126'),
#   'Summary Process'),
#  (130403,
#   'Monteiro, Lanier',
#   ('Property Address',
#    '97',
#    'Devon',
#    'Street',
#    '2',
#    'Dorchester',
#    'MA',
#    '02121'),
#   'Summary Process'),
#  (130404,
#   'Castiglioni, Jillian',
#   ('Property Address', '25', 'Park', 'Street', 'Blackstone', 'MA', '01504'),
#   'Worcester Housing Court'),
#  (130404,
#   'Beane, Carl',
#   ('Property Address', '25', 'Park', 'Street', 'Blackstone', 'MA', '01504'),
#   'Worcester Housing Court'),
#  (130405,
#   'Council, Letica',
#   ('Property Address',
#    '1301',
#    'Main',
#    'Street',
#    '2',
#    'Fitchburg',
#    'MA',
#    '01420'),
#   'Summary Process'),
#  (130406,
#   'English, Gloria',
#   ('Property Address', '251', 'Tacoma', 'Street', 'Worcester', 'MA', '01605'),
#   'Worcester Housing Court'),
#  (130406,
#   'Mangabang, David',
#   ('Property Address', '251', 'Tacoma', 'Street', 'Worcester', 'MA', '01605'),
#   'Worcester Housing Court'),
#  (130407,
#   'Rodrigues, Jasmine',
#   ('Property Address',
#    '135',
#    'West',
#    'Main',
#    'Street',
#    'Unit 6',
#    'Marlborough',
#    'MA',
#    '01752'),
#   'Summary Process'),
#  (130407,
#   'Ruby, Steven Anthony',
#   ('Property Address',
#    '135',
#    'West',
#    'Main',
#    'Street',
#    'Unit 6',
#    'Marlborough',
#    'MA',
#    '01752'),
#   'Summary Process'),
#  (130408,
#   'Clyde, Tamarah',
#   ('Property Address',
#    '62',
#    'Goddard',
#    'Street',
#    '2',
#    'Lunenburg',
#    'MA',
#    '01462'),
#   'Summary Process')]

# %% [markdown]
# Also save with pandas:

# %%
import pandas as pd

# %%
df = pd.DataFrame(new_collection)

# %%
df
# Out:
#              0                     1  \
# 0            1        Duong Au, Phat
# 1            2          Jolly, Kerri
# 2            2      Staples, Richard
# 3            3          Milord, Luna
# 4            4      Figueroa, Alicia
# 5            5       Sanchez, Santos
# 6            6       Rojas, Glicelia
# 7            7       Montanez, Marty
# 8            7        Sieger, Ossana
# 9            8        Auston, Sharon
# 10           9         Orr, Jennifer
# 11          10      Hartwell, Donald
# 12          11         Girard, Steve
# 13          12       Pankins, Rachel
# 14          13        Gregory, Irene
# 15          14     Williams, Ratsomy
# 16          14        Jackson, Louis
# 17          14     Jackson, Cathrine
# 18          15         Marsh, Michal
# 19          16     Repizo, Elizabeth
# 20          17        Chandler, Rene
# 21          18   Jaskiewicz, Kandice
# 22          19          Greer, Sammy
# 23          20      Antigua, Ismeyly
# 24          21      Brigham, Jeffrey
# 25          22   Figueroa, Johana D.
# 26          23     Washington, Liana
# 27          24      Flintroy, Jerome
# 28          25          Ivera, Zulma
# 29          26         Maynard, Anne
# ...        ...                   ...
# 169599  130388          Guy, Yolanda
# 169600  130389         Hogan, Joshua
# 169601  130389       McFadden, Kerri
# 169602  130390      Doherty, Francis
# 169603  130390    Cooney-Gray, Karen
# 169604  130391       Maldonado, Iris
# 169605  130392       Foley, Jennifer
# 169606  130393       Roman, Caroline
# 169607  130393    Carattini, Eduardo
# 169608  130394         Farrick, Mark
# 169609  130395        Roman, Natasha
# 169610  130396     Coriano, Lucianne
# 169611  130396       Coriano, Luis O
# 169612  130397       Hardy, Patricia
# 169613  130398       Harris, Lovette
# 169614  130398       Harris, Greykia
# 169615  130398      Harris, Jayuanna
# 169616  130399           Boyd, Raina
# 169617  130400   Billingsley, Latoya
# 169618  130401      Rodriquez, Nancy
# 169619  130402         Mason, Tracey
# 169620  130403      Monteiro, Lanier
# 169621  130404  Castiglioni, Jillian
# 169622  130404           Beane, Carl
# 169623  130405       Council, Letica
# 169624  130406       English, Gloria
# 169625  130406      Mangabang, David
# 169626  130407    Rodrigues, Jasmine
# 169627  130407  Ruby, Steven Anthony
# 169628  130408        Clyde, Tamarah
#
#                                                         2  \
# 0       (Property Address, 279, 2nd Floor, Lawrence, M...
# 1       (Property Address, 34, #1, 1st Fl, Salem, MA, ...
# 2       (Property Address, 34, #1, 1st Fl, Salem, MA, ...
# 3              (Property Address, 3, #4, Lynn, MA, 01902)
# 4       (Property Address, 64, Apt. 1L, Springfield, M...
# 5        (Property Address, 78-T, Springfield, MA, 01108)
# 6        (Property Address, 302, #2A, Holyoke, MA, 01040)
# 7          (Property Address, 25, Springfield, MA, 01107)
# 8          (Property Address, 25, Springfield, MA, 01107)
# 9       (Property Address, 8, #1, Springfield, MA, 01109)
# 10      (Property Address, 20, Apt 3N, New Bedford, MA...
# 11        (Property Address, 62, #11, Taunton, MA, 02780)
# 12      (Property Address, 107, Store Fron, New Bedfor...
# 13      (Property Address, 95, Apartment, Dorchester C...
# 14      (Property Address, 430, Apt. #206, Boston, MA,...
# 15      (Property Address, 67, Dorchester Center, MA, ...
# 16      (Property Address, 67, Dorchester Center, MA, ...
# 17      (Property Address, 67, Dorchester Center, MA, ...
# 18          (Property Address, 432, Hyde Park, MA, 02136)
# 19        (Property Address, 187A, Dorchester, MA, 02121)
# 20      (Property Address, 33, apt #3, Dorchester, MA,...
# 21      (Property Address, 299, Apt. #3B, Gardner, MA,...
# 22           (Property Address, 15, Worcester, MA, 01605)
# 23            (Property Address, 5, Haverhill, MA, 01830)
# 24      (Property Address, 158, #J10, Billerica, MA, 0...
# 25         (Property Address, 99, Springfield, MA, 01109)
# 26      (Property Address, 156, Apt F, Pittsfield, MA,...
# 27         (Property Address, 61, Springfield, MA, 01109)
# 28      (Property Address, 92, 1Fl, Springfield, MA, 0...
# 29      (Property Address, 208, Apt 1st Fl, North Attl...
# ...                                                   ...
# 169599  (Property Address, 378, Summer Street, 2, Lynn...
# 169600  (Property Address, 822, Ames Hill, Drive, Tewk...
# 169601  (Property Address, 822, Ames Hill, Drive, Tewk...
# 169602  (Property Address, 14, Cross Street, 2, Lowell...
# 169603  (Property Address, 14, Cross Street, 2, Lowell...
# 169604  (Property Address, 41, Freeman Street, 1, Have...
# 169605  (Property Address, 82, Brick Kiln Road, 10-101...
# 169606  (Property Address, 138, Sargeant, Street, 501,...
# 169607  (Property Address, 138, Sargeant, Street, 501,...
# 169608  (Property Address, 250, Main, Street, 6, Easth...
# 169609  (Property Address, 420, Main, Street, 72, Agaw...
# 169610  (Property Address, 131, Farnum, Drive, Holyoke...
# 169611  (Property Address, 131, Farnum, Drive, Holyoke...
# 169612  (Property Address, 27, Montebello, Road, 1B, J...
# 169613  (Property Address, 55, Franklin Hill, Avenue, ...
# 169614  (Property Address, 55, Franklin Hill, Avenue, ...
# 169615  (Property Address, 55, Franklin Hill, Avenue, ...
# 169616  (Property Address, 352, Norfolk, Street, 3, Do...
# 169617  (Property Address, 16-18, Speedwell, Street, 3...
# 169618  (Property Address, 19, Westgate, Road, 2, Ches...
# 169619  (Property Address, 54, Greendale, Road, 2L, Ma...
# 169620  (Property Address, 97, Devon, Street, 2, Dorch...
# 169621  (Property Address, 25, Park, Street, Blackston...
# 169622  (Property Address, 25, Park, Street, Blackston...
# 169623  (Property Address, 1301, Main, Street, 2, Fitc...
# 169624  (Property Address, 251, Tacoma, Street, Worces...
# 169625  (Property Address, 251, Tacoma, Street, Worces...
# 169626  (Property Address, 135, West, Main, Street, Un...
# 169627  (Property Address, 135, West, Main, Street, Un...
# 169628  (Property Address, 62, Goddard, Street, 2, Lun...
#
#                                3
# 0        Northeast Housing Court
# 1        Northeast Housing Court
# 2        Northeast Housing Court
# 3        Northeast Housing Court
# 4          Western Housing Court
# 5          Western Housing Court
# 6          Western Housing Court
# 7          Western Housing Court
# 8          Western Housing Court
# 9          Western Housing Court
# 10               Summary Process
# 11               Summary Process
# 12               Summary Process
# 13               Summary Process
# 14               Summary Process
# 15               Summary Process
# 16               Summary Process
# 17               Summary Process
# 18               Summary Process
# 19               Summary Process
# 20               Summary Process
# 21       Worcester Housing Court
# 22       Worcester Housing Court
# 23       Northeast Housing Court
# 24       Northeast Housing Court
# 25         Western Housing Court
# 26               Summary Process
# 27         Western Housing Court
# 28         Western Housing Court
# 29               Summary Process
# ...                          ...
# 169599           Summary Process
# 169600           Summary Process
# 169601           Summary Process
# 169602           Summary Process
# 169603           Summary Process
# 169604   Northeast Housing Court
# 169605           Summary Process
# 169606     Western Housing Court
# 169607     Western Housing Court
# 169608  Franklin/Hampshire Court
# 169609     Western Housing Court
# 169610     Western Housing Court
# 169611     Western Housing Court
# 169612           Summary Process
# 169613           Summary Process
# 169614           Summary Process
# 169615           Summary Process
# 169616           Summary Process
# 169617           Summary Process
# 169618           Summary Process
# 169619           Summary Process
# 169620           Summary Process
# 169621   Worcester Housing Court
# 169622   Worcester Housing Court
# 169623           Summary Process
# 169624   Worcester Housing Court
# 169625   Worcester Housing Court
# 169626           Summary Process
# 169627           Summary Process
# 169628           Summary Process
#
# [169629 rows x 4 columns]

# %%
df.to_csv("housing_dataframe")

# %% [markdown]
# # Reloading the data

# %%
df = pd.read_csv("housing_dataframe")

# %%
# %%time

# dictionary for saving data
my_dict = {}

# initialize a counter to see how many files were processed
count = 0

for name in os.listdir():
    
    # only process the html files.  Don't process
    # hidden files, .ipynb files, directories, et cetera
    if name.endswith(".html"):
        
        # in case you want to see how many files were processed
        count += 1
        
        # open and read the html
        with open(name,"r") as f:
            text = f.read()
            
        # turn the text into beautiful soup for data extraction
        soup = bs4.BeautifulSoup(text,"html.parser")
        
        # grab the fields we're currently interested in
        data = get_people_class_address(soup)
        
        # store the data by case number in our dictionary
        my_dict[data["case"]] = data
        
        new_file_name = data["case"] + ".html"
        
        # try to rename the file to match the case ID
        try:
            # rename if possible
            os.rename(name,new_file_name)
            
        except:
            # if the above errors, it's because the
            # case was processed in another file.
            
            # delete redundant files
            os.remove(name)
# Out:
# Wall time: 2.28 s

# %%
with open("test.html","w") as f:
    f.write("\n")

# %%
os.remove("test.html")

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '18H84CV000528.html',
#  '18H84CV000529.html',
#  '18H84CV000530.html',
#  '18H84CV000531.html',
#  '18H84CV000532.html',
#  '18H84CV000534.html',
#  '18H84CV000535.html',
#  '18H84CV000536.html',
#  '18H84CV000537.html',
#  '18H84CV000547.html',
#  '18H84CV000548.html',
#  '18H84CV000550.html',
#  '18H84CV000551.html',
#  '18H84CV000552.html',
#  '18H84CV000553.html',
#  '18H84CV000554.html',
#  '18H84CV000559.html',
#  '18H84CV000566.html',
#  '18H84CV000567.html',
#  '18H84CV000568.html',
#  '18H84CV000570.html',
#  '18H84CV000574.html',
#  '18H84SP004018.html',
#  '18H84SP004019.html',
#  '18H84SP004020.html',
#  '18H84SP004021.html',
#  '18H84SP004022.html',
#  '18H84SP004024.html',
#  '18H84SP004026.html',
#  '18H84SP004027.html',
#  '18H84SP004028.html',
#  '18H84SP004029.html',
#  '18H84SP004030.html',
#  '18H84SP004031.html',
#  '18H84SP004032.html',
#  '18H84SP004033.html',
#  '18H84SP004035.html',
#  '18H84SP004036.html',
#  '18H84SP004037.html',
#  '18H84SP004038.html',
#  '18H84SP004040.html',
#  '18H84SP004042.html',
#  '18H84SP004044.html',
#  '18H84SP004050.html',
#  '18H84SP004051.html',
#  '18H84SP004055.html',
#  '18H84SP004056.html',
#  '18H84SP004057.html',
#  '18H84SP004059.html',
#  '18H84SP004060.html',
#  '18H84SP004061.html',
#  '18H84SP004062.html',
#  '18H84SP004063.html',
#  '18H84SP004064.html',
#  '18H84SP004067.html',
#  '18H84SP004068.html',
#  '18H84SP004069.html',
#  '18H84SP004070.html',
#  '18H84SP004071.html',
#  '18H84SP004072.html',
#  '18H84SP004073.html',
#  '18H84SP004074.html',
#  '18H84SP004076.html',
#  '18H84SP004079.html',
#  '18H84SP004080.html',
#  '18H84SP004081.html',
#  '18H84SP004082.html',
#  '18H84SP004083.html',
#  '18H84SP004084.html',
#  '18H84SP004085.html',
#  '18H84SP004087.html',
#  '18H84SP004088.html',
#  '18H84SP004089.html',
#  '18H84SP004091.html',
#  '18H84SP004092.html',
#  '18H84SP004093.html',
#  '18H84SP004094.html',
#  '18H84SP004095.html',
#  '18H84SP004096.html',
#  '18H84SP004097.html',
#  '18H84SP004099.html',
#  '18H84SP004100.html',
#  '18H84SP004103.html',
#  '18H84SP004104.html',
#  '18H84SP004105.html',
#  '18H84SP004106.html',
#  '18H84SP004107.html',
#  '18H84SP004108.html',
#  '18H84SP004110.html',
#  'Data prep.ipynb']

# %%
file_name
# Out:
# '18H84CV000530.html'

# %%
my_dict
# Out:
# {'18H84CV000528': {'Defendant': [('Forde', 'Lotlene')],
#   'Plaintiff': [('Clarke', 'Sonia')],
#   'case': '18H84CV000528',
#   'city': 'Dorchester Center, MA, 02124',
#   'close date': '09/14/2018',
#   'file date': '09/04/2018',
#   'street': '44 Stockton Street, 3'},
#  '18H84CV000529': {'Defendant': [('Ramos Rodriguez', 'Maria')],
#   'Plaintiff': [('Ramos', 'Angel'), ('Jin', 'Xiaxia')],
#   'case': '18H84CV000529',
#   'city': 'Roxbury Crossing, MA, 02120',
#   'close date': '09/24/2018',
#   'file date': '09/04/2018',
#   'street': '22 Saint Alphonsus Street, A'},
#  '18H84CV000530': {'Defendant': [('Zhong Xing Long USA Investments',)],
#   'Plaintiff': [('Baez', 'Carmen')],
#   'case': '18H84CV000530',
#   'city': 'Chelsea, MA, 02150',
#   'close date': '09/14/2018',
#   'file date': '09/05/2018',
#   'street': '944 Broadway, 3'},
#  '18H84CV000531': {'Defendant': [('Boston Housing Authority',)],
#   'Plaintiff': [('Allison', 'Rita')],
#   'case': '18H84CV000531',
#   'city': 'Dorchester Center, MA, 02124',
#   'close date': '09/12/2018',
#   'file date': '09/05/2018',
#   'street': '91 Ames Street, Box C 237'},
#  '18H84CV000532': {'Defendant': [('Villalobos', 'Property Manager', 'Carmen')],
#   'Plaintiff': [('Deas', 'Cullen')],
#   'case': '18H84CV000532',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '09/18/2018',
#   'file date': '09/05/2018',
#   'street': '1 Nazing Court, 14'},
#  '18H84CV000534': {'Defendant': [('Lopes', 'Jose'),
#    ('Lopes', 'Ricardo'),
#    ('Lopes', 'Fransico')],
#   'Plaintiff': [('McDonald', 'Deneine')],
#   'case': '18H84CV000534',
#   'city': 'Dorchester Center, MA, 02124',
#   'close date': '09/18/2018',
#   'file date': '09/05/2018',
#   'street': '9 Kenberma Road, 2 & 3'},
#  '18H84CV000535': {'Defendant': [('Ayala', 'Angel')],
#   'Plaintiff': [('Arch Development LP',)],
#   'case': '18H84CV000535',
#   'city': 'Roxbury Crossing, MA, 02120',
#   'close date': '09/18/2018',
#   'file date': '09/06/2018',
#   'street': '1049 Tremont Street, 42'},
#  '18H84CV000536': {'Defendant': [('Murriel Toussaint', 'Rogera C.')],
#   'Plaintiff': [('Greene', 'Nieta M.')],
#   'case': '18H84CV000536',
#   'city': 'Cambridge, MA, 02139',
#   'close date': '09/18/2018',
#   'file date': '09/06/2018',
#   'street': '38 Howard, Street'},
#  '18H84CV000537': {'Defendant': [('Waite', 'Austin')],
#   'Plaintiff': [('Thompson', 'Samira')],
#   'case': '18H84CV000537',
#   'city': 'Dorchester, MA, 02125',
#   'close date': '09/07/2018',
#   'file date': '09/06/2018',
#   'street': '1 Dove, Street'},
#  '18H84CV000547': {'Defendant': [('Blaisdell', 'Stephanie')],
#   'Plaintiff': [('Sheals', 'Sandra')],
#   'case': '18H84CV000547',
#   'city': 'Dorchester, MA, 02122',
#   'close date': '09/20/2018',
#   'file date': '09/12/2018',
#   'street': '56 Charles Street, 3'},
#  '18H84CV000548': {'Defendant': [('McKinlay', 'Shauneen')],
#   'Plaintiff': [('Rossell', 'Haley A')],
#   'case': '18H84CV000548',
#   'city': 'Roxbury Crossing, MA, 02120',
#   'close date': '09/24/2018',
#   'file date': '09/12/2018',
#   'street': '16 Iroquois Street, 1'},
#  '18H84CV000550': {'Defendant': [('Corcoran Jennison Dev. Co.',)],
#   'Plaintiff': [('McGeorge', 'John')],
#   'case': '18H84CV000550',
#   'city': 'Dorchester, MA, 02125',
#   'close date': '09/28/2018',
#   'file date': '09/14/2018',
#   'street': '48 Peninsula Place, 106'},
#  '18H84CV000551': {'Defendant': [('Dejesus Osorio', 'Felipe'),
#    ('Dejesus Osorio', 'Delia')],
#   'Plaintiff': [('Grant Manor,L.P.',)],
#   'case': '18H84CV000551',
#   'city': 'Boston, MA, 02118',
#   'close date': '10/01/2018',
#   'file date': '09/17/2018',
#   'street': '1850 Washington Street, 709'},
#  '18H84CV000552': {'Defendant': [('Pugsley', 'Jennifer')],
#   'Plaintiff': [('Moore', 'Naomi A.')],
#   'case': '18H84CV000552',
#   'city': 'Mattapan, MA, 02126',
#   'close date': '09/24/2018',
#   'file date': '09/17/2018',
#   'street': '50 Fairlawn Avenue, E-7'},
#  '18H84CV000553': {'Defendant': [('Gayle', 'Kerry-Ann')],
#   'Plaintiff': [('Frawley-Delle Apartments',)],
#   'case': '18H84CV000553',
#   'city': '',
#   'close date': '09/28/2018',
#   'file date': '09/18/2018',
#   'street': ''},
#  '18H84CV000554': {'Defendant': [('Buckley', 'Susan')],
#   'Plaintiff': [('Miranda', 'Jonatas'), ('Schirick', 'Elizabeth')],
#   'case': '18H84CV000554',
#   'city': 'Roslindale, MA, 02131',
#   'close date': '10/03/2018',
#   'file date': '09/18/2018',
#   'street': '67 Cohasset Street, 2'},
#  '18H84CV000559': {'Defendant': [('Burroughs', 'Casey')],
#   'Plaintiff': [('Waterside Development Group', 'LLC')],
#   'case': '18H84CV000559',
#   'city': 'Boston, MA, 02210',
#   'close date': '10/01/2018',
#   'file date': '09/20/2018',
#   'street': '505 Congress Street, 308'},
#  '18H84CV000566': {'Defendant': [('Jay Leary Manager of Corcoran Management',)],
#   'Plaintiff': [('Inspectional Services Department',)],
#   'case': '18H84CV000566',
#   'city': 'Brighton, MA, 02135',
#   'close date': '09/24/2018',
#   'file date': '09/24/2018',
#   'street': '31 Jette Court, 759'},
#  '18H84CV000567': {'Defendant': [('Smith', 'Jim')],
#   'Plaintiff': [('Ingram', 'Monique')],
#   'case': '18H84CV000567',
#   'city': 'Dorchester Center, MA, 02124',
#   'close date': '09/25/2018',
#   'file date': '09/24/2018',
#   'street': '90 Corbet Street, 2'},
#  '18H84CV000568': {'Defendant': [('Blinn', 'William')],
#   'Plaintiff': [('Building Department',)],
#   'case': '18H84CV000568',
#   'city': 'Boston, MA, 02116',
#   'close date': '09/25/2018',
#   'file date': '09/25/2018',
#   'street': '215 West Canton, Street'},
#  '18H84CV000570': {'Defendant': [('Ferris', 'Shannon')],
#   'Plaintiff': [('Cautilli', 'Carmelo Leo')],
#   'case': '18H84CV000570',
#   'city': 'Brighton, MA, 02135',
#   'close date': '10/02/2018',
#   'file date': '09/25/2018',
#   'street': '293-295 Market, Street'},
#  '18H84CV000574': {'Defendant': [('Rodriguez', 'Stefanie')],
#   'Plaintiff': [('Perdomo', 'Doris')],
#   'case': '18H84CV000574',
#   'city': 'Boston, MA, 02118',
#   'close date': '10/03/2018',
#   'file date': '09/26/2018',
#   'street': '968 Massachusetts, Avenue'},
#  '18H84SP004018': {'Defendant': [('Octavius', 'Rodelaire')],
#   'Plaintiff': [('Denton', 'Gladstone')],
#   'case': '18H84SP004018',
#   'city': 'Mattapan, MA, 02126',
#   'close date': '10/01/2018',
#   'file date': '09/04/2018',
#   'street': '1288A Blue Hill, Avenue'},
#  '18H84SP004019': {'Defendant': [('Turner', 'Lawanda'), ('Burton', 'Nicole')],
#   'Plaintiff': [('Second City Properties', 'LLC')],
#   'case': '18H84SP004019',
#   'city': 'Chelsea, MA, 02150',
#   'close date': '09/17/2018',
#   'file date': '09/04/2018',
#   'street': '76 Clarke Avenue, 2'},
#  '18H84SP004020': {'Defendant': [('Bao', 'Yang')],
#   'Plaintiff': [('PRG BD Investors', 'LLC')],
#   'case': '18H84SP004020',
#   'city': 'Boston, MA, 02115',
#   'close date': '09/13/2018',
#   'file date': '09/04/2018',
#   'street': '30 Dalton Street, 1004'},
#  '18H84SP004021': {'Defendant': [('Goldfeld', 'Frederico')],
#   'Plaintiff': [('PRG BD Investors', 'LLC')],
#   'case': '18H84SP004021',
#   'city': 'Boston, MA, 02115',
#   'close date': '09/18/2018',
#   'file date': '09/04/2018',
#   'street': '30 Dalton Street, 2208'},
#  '18H84SP004022': {'Defendant': [('Chowdhury', 'Nidal')],
#   'Plaintiff': [('64 VWS Owner', 'LLC')],
#   'case': '18H84SP004022',
#   'city': 'Revere, MA, 02151',
#   'close date': '09/13/2018',
#   'file date': '09/04/2018',
#   'street': '660 Ocean Avenue, 418'},
#  '18H84SP004024': {'Defendant': [('Jackson', 'Felorah')],
#   'Plaintiff': [('POAH Communities', 'LLC')],
#   'case': '18H84SP004024',
#   'city': 'Cambridge, MA, 02138',
#   'close date': '09/13/2018',
#   'file date': '09/04/2018',
#   'street': '239 Garden Street, 2'},
#  '18H84SP004026': {'Defendant': [('Harvey', 'Taja')],
#   'Plaintiff': [('Clarendon Hill Somerville LP',)],
#   'case': '18H84SP004026',
#   'city': 'Somerville, MA, 02144',
#   'close date': '09/14/2018',
#   'file date': '09/04/2018',
#   'street': '1370 Broadway, R 03N'},
#  '18H84SP004027': {'Defendant': [('Conoscienti', 'Thomas')],
#   'Plaintiff': [('Clarendon Hill Somerville LP',)],
#   'case': '18H84SP004027',
#   'city': 'Somerville, MA, 02144',
#   'close date': '09/14/2018',
#   'file date': '09/04/2018',
#   'street': '1370 Broadway, 08D'},
#  '18H84SP004028': {'Defendant': [('Gordon', 'Chanelle')],
#   'Plaintiff': [('Clarendon Hill Somerville LP',)],
#   'case': '18H84SP004028',
#   'city': 'Somerville, MA, 02144',
#   'close date': '09/14/2018',
#   'file date': '09/04/2018',
#   'street': '1374 Broadway, C 01N'},
#  '18H84SP004029': {'Defendant': [('Esturban', 'Zeiri'),
#    ('Kelley', 'Jonathan Justin')],
#   'Plaintiff': [('Roxbury Residential Realty Trust',)],
#   'case': '18H84SP004029',
#   'city': 'Dorchester Center, MA, 02124',
#   'close date': '10/01/2018',
#   'file date': '09/04/2018',
#   'street': '1111 Blue Hill Avenue, B2'},
#  '18H84SP004030': {'Defendant': [('Davis', 'Jeffrey')],
#   'Plaintiff': [('Weston Associates Management Company', 'Inc.')],
#   'case': '18H84SP004030',
#   'city': 'East Boston, MA, 02128',
#   'close date': '09/14/2018',
#   'file date': '09/04/2018',
#   'street': '810 Border Street, 707'},
#  '18H84SP004031': {'Defendant': [('HomeStart', 'Inc.')],
#   'Plaintiff': [('Dilendick', 'Alec')],
#   'case': '18H84SP004031',
#   'city': 'Dorchester, MA, 02125',
#   'close date': '09/14/2018',
#   'file date': '09/04/2018',
#   'street': '47 Coleman Street, 2'},
#  '18H84SP004032': {'Defendant': [('Gerald', 'Sequoia Janine')],
#   'Plaintiff': [('77 Ruthven Street', 'LLC')],
#   'case': '18H84SP004032',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '10/09/2018',
#   'file date': '09/04/2018',
#   'street': '77 Ruthven Street, 2'},
#  '18H84SP004033': {'Defendant': [('Dorvil', 'Eugene')],
#   'Plaintiff': [('Charles', 'Philippe')],
#   'case': '18H84SP004033',
#   'city': 'Mattapan, MA, 02126',
#   'close date': '10/04/2018',
#   'file date': '09/04/2018',
#   'street': '33 Wellington Street, 3'},
#  '18H84SP004035': {'Defendant': [('Zhouwei', 'Lin'), ('Zhang', 'Yuxin')],
#   'Plaintiff': [('Qianlong criterian ventures', 'LLC')],
#   'case': '18H84SP004035',
#   'city': 'Dorchester, MA, 02125',
#   'close date': '09/18/2018',
#   'file date': '09/04/2018',
#   'street': '25 Morrissey Boulevard, 1541'},
#  '18H84SP004036': {'Defendant': [('Barros', 'Joyce')],
#   'Plaintiff': [('White', 'Ed')],
#   'case': '18H84SP004036',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '09/21/2018',
#   'file date': '09/04/2018',
#   'street': '82 Fayston Street, 3'},
#  '18H84SP004037': {'Defendant': [('Jones', 'Relicia')],
#   'Plaintiff': [('Shuster', 'Gary')],
#   'case': '18H84SP004037',
#   'city': 'Dorchester Center, MA, 02124',
#   'close date': '09/17/2018',
#   'file date': '09/04/2018',
#   'street': '50 Burt Street, 1'},
#  '18H84SP004038': {'Defendant': [('Giaff', 'Kwesi')],
#   'Plaintiff': [('Mohamoud', 'Mohamoud')],
#   'case': '18H84SP004038',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '09/14/2018',
#   'file date': '09/04/2018',
#   'street': '241 Columbia Road, 2'},
#  '18H84SP004040': {'Defendant': [('Radh', 'Lavon')],
#   'Plaintiff': [('Chowdhury', 'Salim')],
#   'case': '18H84SP004040',
#   'city': 'Dorchester, MA, 02125',
#   'close date': '09/24/2018',
#   'file date': '09/04/2018',
#   'street': '2 Howe Terrace, 2'},
#  '18H84SP004042': {'Defendant': [('Rose', 'Renford')],
#   'Plaintiff': [('McPherson', 'Lucian')],
#   'case': '18H84SP004042',
#   'city': 'Dorchester, MA, 02125',
#   'close date': '09/18/2018',
#   'file date': '09/04/2018',
#   'street': '31 Greenock Street, 1'},
#  '18H84SP004044': {'Defendant': [('Francis', 'Amina')],
#   'Plaintiff': [('River Street LJS', 'LLC')],
#   'case': '18H84SP004044',
#   'city': 'Hyde Park, MA, 02136',
#   'close date': '09/13/2018',
#   'file date': '09/04/2018',
#   'street': '1140 River Street, 3F'},
#  '18H84SP004050': {'Defendant': [('Ming', 'Vanessa')],
#   'Plaintiff': [('Peabody Properties', 'Inc.')],
#   'case': '18H84SP004050',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '09/17/2018',
#   'file date': '09/04/2018',
#   'street': '166 Seaver Street, 8'},
#  '18H84SP004051': {'Defendant': [('Hart', 'Virgie')],
#   'Plaintiff': [('Theirse', 'Angella')],
#   'case': '18H84SP004051',
#   'city': 'Dorchester Center, MA, 02124',
#   'close date': '09/18/2018',
#   'file date': '09/05/2018',
#   'street': '15 Hannon, Street'},
#  '18H84SP004055': {'Defendant': [('Green', 'Jazmine')],
#   'Plaintiff': [('Dudley Village North LP',)],
#   'case': '18H84SP004055',
#   'city': 'Dorchester, MA, 02125',
#   'close date': '09/18/2018',
#   'file date': '09/05/2018',
#   'street': '584 Dudley Street, 301'},
#  '18H84SP004056': {'Defendant': [('Bishop', 'Tricia')],
#   'Plaintiff': [('DB 618 Dudley Street LLC',)],
#   'case': '18H84SP004056',
#   'city': 'Dorchester, MA, 02125',
#   'close date': '09/14/2018',
#   'file date': '09/05/2018',
#   'street': '618 Dudley Street, 1'},
#  '18H84SP004057': {'Defendant': [('Tejeda', 'Elaine Victoria')],
#   'Plaintiff': [('Lorenzo Pitts', 'Inc.')],
#   'case': '18H84SP004057',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '09/14/2018',
#   'file date': '09/05/2018',
#   'street': '128 Intervale Street, 5'},
#  '18H84SP004059': {'Defendant': [('Munoz DeRosa', 'Diana Christina')],
#   'Plaintiff': [('Lorenzo Pitts', 'Inc.')],
#   'case': '18H84SP004059',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '09/18/2018',
#   'file date': '09/05/2018',
#   'street': '40 Lawrence Avenue, 17'},
#  '18H84SP004060': {'Defendant': [('Allen', 'Karen')],
#   'Plaintiff': [('Lorenzo Pitts', 'Inc.')],
#   'case': '18H84SP004060',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '09/13/2018',
#   'file date': '09/05/2018',
#   'street': '86 Fayston Street, 4'},
#  '18H84SP004061': {'Defendant': [('Hernandez', 'Adolfo')],
#   'Plaintiff': [('Lorenzo Pitts', 'Inc.')],
#   'case': '18H84SP004061',
#   'city': 'Roxbury, MA, 02119',
#   'close date': '09/17/2018',
#   'file date': '09/05/2018',
#   'street': '1 Gardner Street, 41'},
#  '18H84SP004062': {'Defendant': [('Leonardo', 'Maria')],
#   'Plaintiff': [('Lorenzo Pitts', 'Inc.')],
#   'case': '18H84SP004062',
#   'city': 'Jamaica Plain, MA, 02130',
#   'close date': '09/17/2018',
#   'file date': '09/05/2018',
#   'street': '223 Heath Street, 3'},
#  '18H84SP004063': {'Defendant': [('Rodrigues', 'Anthony')],
#   'Plaintiff': [('MVC 40B', 'LLC')],
#   'case': '18H84SP004063',
#   'city': 'Boston, MA, 02116',
#   'close date': '09/14/2018',
#   'file date': '09/05/2018',
#   'street': '40 #613 Berkeley Street, 224'},
#  '18H84SP004064': {'Defendant': [('Ozman', 'Abukar')],
#   'Plaintiff': [('Lorenzo Pitts', 'Inc.')],
#   'case': '18H84SP004064',
#   'city': 'Roxbury, MA, 02119',
#   'close date': '09/18/2018',
#   'file date': '09/05/2018',
#   'street': '1 Gardner Street, 215'},
#  '18H84SP004067': {'Defendant': [('Alvarez', 'Marcia')],
#   'Plaintiff': [('Winn Management Company',)],
#   'case': '18H84SP004067',
#   'city': 'Brighton, MA, 02135',
#   'close date': '10/01/2018',
#   'file date': '09/05/2018',
#   'street': '256 North Beacon Street, 077'},
#  '18H84SP004068': {'Defendant': [('Miles', 'Jaquel')],
#   'Plaintiff': [('Winn Management Company',)],
#   'case': '18H84SP004068',
#   'city': 'Brighton, MA, 02135',
#   'close date': '09/27/2018',
#   'file date': '09/05/2018',
#   'street': '75 Faneuil Street, 221'},
#  '18H84SP004069': {'Defendant': [('Wright', 'Hester')],
#   'Plaintiff': [('Trinity Management', 'LLC')],
#   'case': '18H84SP004069',
#   'city': 'Mattapan, MA, 02126',
#   'close date': '10/01/2018',
#   'file date': '09/05/2018',
#   'street': '249 River Street, 524'},
#  '18H84SP004070': {'Defendant': [('Burston', 'John')],
#   'Plaintiff': [('Trinity Management', 'LLC')],
#   'case': '18H84SP004070',
#   'city': '',
#   'close date': '09/14/2018',
#   'file date': '09/05/2018',
#   'street': ''},
#  '18H84SP004071': {'Defendant': [('Williams', 'Della')],
#   'Plaintiff': [('Trinity Management', 'LLC')],
#   'case': '18H84SP004071',
#   'city': 'Mattapan, MA, 02126',
#   'close date': '09/18/2018',
#   'file date': '09/05/2018',
#   'street': '249 River Street, 426'},
#  '18H84SP004072': {'Defendant': [('Washington', 'Victoria')],
#   'Plaintiff': [('Trinity Management', 'LLC')],
#   'case': '18H84SP004072',
#   'city': 'Mattapan, MA, 02126',
#   'close date': '09/13/2018',
#   'file date': '09/05/2018',
#   'street': '229 River Street, 301'},
#  '18H84SP004073': {'Defendant': [('White', 'Elaine')],
#   'Plaintiff': [('Trinity Management', 'LLC')],
#   'case': '18H84SP004073',
#   'city': 'Mattapan, MA, 02126',
#   'close date': '09/14/2018',
#   'file date': '09/05/2018',
#   'street': '231 River Street, B1-104'},
#  '18H84SP004074': {'Defendant': [('Johnson', 'Latoya')],
#   'Plaintiff': [('Swaray', 'Jean')],
#   'case': '18H84SP004074',
#   'city': 'Dorchester Center, MA, 02124',
#   'close date': '09/24/2018',
#   'file date': '09/05/2018',
#   'street': '135 Spencer Street, 3'},
#  '18H84SP004076': {'Defendant': [('Tyrance', 'Carissa')],
#   'Plaintiff': [('Hill', 'Don'), ('Scott', 'Venice')],
#   'case': '18H84SP004076',
#   'city': 'Mattapan, MA, 02126',
#   'close date': '10/02/2018',
#   'file date': '09/05/2018',
#   'street': '48 Rosewood Street, 1'},
#  '18H84SP004079': {'Defendant': [('Jones', 'Dion')],
#   'Plaintiff': [('Ross', 'Jane M.')],
#   'case': '18H84SP004079',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '10/05/2018',
#   'file date': '09/05/2018',
#   'street': '2 Harlem Street, 3'},
#  '18H84SP004080': {'Defendant': [('Patterson', 'Crystal')],
#   'Plaintiff': [('Harrison', 'Kevin')],
#   'case': '18H84SP004080',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '10/01/2018',
#   'file date': '09/05/2018',
#   'street': '41 Waumbeck Street, RM 2R'},
#  '18H84SP004081': {'Defendant': [('Batista', 'Yorkiris')],
#   'Plaintiff': [('The Community Builders', 'Inc.')],
#   'case': '18H84SP004081',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '09/18/2018',
#   'file date': '09/05/2018',
#   'street': '85 Esmond Street, 22'},
#  '18H84SP004082': {'Defendant': [('Raybine', 'Michael J.')],
#   'Plaintiff': [('Pine Street Inn', 'Inc.')],
#   'case': '18H84SP004082',
#   'city': 'Dorchester, MA, 02122',
#   'close date': '09/17/2018',
#   'file date': '09/05/2018',
#   'street': '85 Homes Avenue, 1'},
#  '18H84SP004083': {'Defendant': [('Creecy', 'Trannee')],
#   'Plaintiff': [("Tenants' Development Corporation",)],
#   'case': '18H84SP004083',
#   'city': 'Boston, MA, 02118',
#   'close date': '09/18/2018',
#   'file date': '09/05/2018',
#   'street': '522 Massachusetts Avenue, 2'},
#  '18H84SP004084': {'Defendant': [('Monroig', 'Angel'), ('Salerno', 'Lisa')],
#   'Plaintiff': [("Tenants' Development Corporation",)],
#   'case': '18H84SP004084',
#   'city': 'Boston, MA, 02118',
#   'close date': '09/18/2018',
#   'file date': '09/05/2018',
#   'street': '508 Massachusetts Avenue, 4'},
#  '18H84SP004085': {'Defendant': [('Valentine', 'Sharon')],
#   'Plaintiff': [('Winn Managed Properties', 'LLC')],
#   'case': '18H84SP004085',
#   'city': 'Mattapan, MA, 02126',
#   'close date': '10/01/2018',
#   'file date': '09/05/2018',
#   'street': '415 River Street, 304'},
#  '18H84SP004087': {'Defendant': [('Ocasio', 'Elenie')],
#   'Plaintiff': [('Winn Managed Properties', 'LLC')],
#   'case': '18H84SP004087',
#   'city': 'Dorchester, MA, 02125',
#   'close date': '09/13/2018',
#   'file date': '09/05/2018',
#   'street': '95 Wayland, Street'},
#  '18H84SP004088': {'Defendant': [('Renick', 'Ella')],
#   'Plaintiff': [('Castillo', 'Luis')],
#   'case': '18H84SP004088',
#   'city': 'Dorchester Center, MA, 02124',
#   'close date': '09/21/2018',
#   'file date': '09/05/2018',
#   'street': '27 Greenock Street, 3'},
#  '18H84SP004089': {'Defendant': [('Evans', 'Dominique')],
#   'Plaintiff': [('The Cooperative of CharlesNEWtown Housing', 'Inc.')],
#   'case': '18H84SP004089',
#   'city': 'Charlestown, MA, 02129',
#   'close date': '09/13/2018',
#   'file date': '09/05/2018',
#   'street': '68 Old Ironside, Way'},
#  '18H84SP004091': {'Defendant': [('King Yau', 'Yung')],
#   'Plaintiff': [('The Cooperative of CharlesNEWtown Housing', 'Inc.')],
#   'case': '18H84SP004091',
#   'city': 'Charlestown, MA, 02129',
#   'close date': '09/13/2018',
#   'file date': '09/05/2018',
#   'street': '99B Old Ironsides, Way'},
#  '18H84SP004092': {'Defendant': [('Jones', 'Jennifer')],
#   'Plaintiff': [('The Cooperative of CharlesNEWtown Housing', 'Inc.')],
#   'case': '18H84SP004092',
#   'city': 'Charlestown, MA, 02129',
#   'close date': '09/18/2018',
#   'file date': '09/05/2018',
#   'street': '96 Old Ironsides, Way'},
#  '18H84SP004093': {'Defendant': [('Ahmed', 'Muhammad'), ('Riaz', 'Ibrahim')],
#   'Plaintiff': [('Equity Residential Management', 'LLC')],
#   'case': '18H84SP004093',
#   'city': 'Boston, MA, 02114',
#   'close date': '09/14/2018',
#   'file date': '09/05/2018',
#   'street': '101 Canal Street, 409'},
#  '18H84SP004094': {'Defendant': [('Aravanis', 'Christos'),
#    ('Deris', 'Alexander'),
#    ('Lanara', 'Ekaterini')],
#   'Plaintiff': [('Equity Residential Management', 'LLC')],
#   'case': '18H84SP004094',
#   'city': 'Boston, MA, 02114',
#   'close date': '09/13/2018',
#   'file date': '09/05/2018',
#   'street': '101 Canal Street, 821'},
#  '18H84SP004095': {'Defendant': [('Bhagchandka', 'Anushka')],
#   'Plaintiff': [('Equity Residential Management', 'LLC')],
#   'case': '18H84SP004095',
#   'city': 'Boston, MA, 02111',
#   'close date': '09/14/2018',
#   'file date': '09/05/2018',
#   'street': '660 Washington Street, 18E'},
#  '18H84SP004096': {'Defendant': [('Castillo', 'Marisol')],
#   'Plaintiff': [('Washington Columbia II LP',)],
#   'case': '18H84SP004096',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '09/17/2018',
#   'file date': '09/05/2018',
#   'street': '50 Columbia Road, 10'},
#  '18H84SP004097': {'Defendant': [('Wright', 'Frankey')],
#   'Plaintiff': [('Washington Columbia II LP',)],
#   'case': '18H84SP004097',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '09/18/2018',
#   'file date': '09/05/2018',
#   'street': '103 Washington Street, 9'},
#  '18H84SP004099': {'Defendant': [('Pena', 'Sonia')],
#   'Plaintiff': [('Quincy Geneva II LP',)],
#   'case': '18H84SP004099',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '09/14/2018',
#   'file date': '09/05/2018',
#   'street': '99 Lawrence Avenue, 1'},
#  '18H84SP004100': {'Defendant': [('Rios', 'Cindy')],
#   'Plaintiff': [('Metro Management Company',)],
#   'case': '18H84SP004100',
#   'city': 'East Boston, MA, 02128',
#   'close date': '09/17/2018',
#   'file date': '09/05/2018',
#   'street': '30 Gove Street, 204'},
#  '18H84SP004103': {'Defendant': [('Henderson', 'Tarshita R.')],
#   'Plaintiff': [('Maloney Properties Inc.',)],
#   'case': '18H84SP004103',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '09/14/2018',
#   'file date': '09/06/2018',
#   'street': '184 Seaver Street, 6'},
#  '18H84SP004104': {'Defendant': [('Jackson', 'Kimberly')],
#   'Plaintiff': [('Maloney Properties Inc.',)],
#   'case': '18H84SP004104',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '09/13/2018',
#   'file date': '09/06/2018',
#   'street': '67 Brookledge Street, 4'},
#  '18H84SP004105': {'Defendant': [('Johnson', 'Tykeia')],
#   'Plaintiff': [('Maloney Properties Inc.',)],
#   'case': '18H84SP004105',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '09/13/2018',
#   'file date': '09/06/2018',
#   'street': '109 Hometead Street, 5'},
#  '18H84SP004106': {'Defendant': [('Plaisival', 'Claudjah S.')],
#   'Plaintiff': [('Maloney Properties Inc.',)],
#   'case': '18H84SP004106',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '09/14/2018',
#   'file date': '09/06/2018',
#   'street': '144 Seaver Street, 7'},
#  '18H84SP004107': {'Defendant': [('Price', 'Dominiquea')],
#   'Plaintiff': [('Maloney Properties Inc.',)],
#   'case': '18H84SP004107',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '09/11/2018',
#   'file date': '09/06/2018',
#   'street': '79 Hutchings Street, 3'},
#  '18H84SP004108': {'Defendant': [('Pollard', 'Nikia')],
#   'Plaintiff': [('Maloney Properties Inc.',)],
#   'case': '18H84SP004108',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '09/14/2018',
#   'file date': '09/06/2018',
#   'street': '83 Hutchings Street, 3'},
#  '18H84SP004110': {'Defendant': [('Rivera', 'Christiana'),
#    ('Carrasquillo', 'Edwin')],
#   'Plaintiff': [('Maloney Properties Inc.',)],
#   'case': '18H84SP004110',
#   'city': 'Dorchester, MA, 02121',
#   'close date': '09/13/2018',
#   'file date': '09/06/2018',
#   'street': '11 Brookledge Street, 8'}}

# %% [markdown]
# # Pandas!
#
# Now that we have data, we need to turn it into a dataframe:

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_dict(my_dict,orient="index")
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#              case                        street                          city  \
# 0   18H84CV000528         44 Stockton Street, 3  Dorchester Center, MA, 02124
# 1   18H84CV000529  22 Saint Alphonsus Street, A   Roxbury Crossing, MA, 02120
# 2   18H84CV000530               944 Broadway, 3            Chelsea, MA, 02150
# 3   18H84CV000531     91 Ames Street, Box C 237  Dorchester Center, MA, 02124
# 4   18H84CV000532            1 Nazing Court, 14         Dorchester, MA, 02121
# 5   18H84CV000534        9 Kenberma Road, 2 & 3  Dorchester Center, MA, 02124
# 6   18H84CV000535       1049 Tremont Street, 42   Roxbury Crossing, MA, 02120
# 7   18H84CV000536             38 Howard, Street          Cambridge, MA, 02139
# 8   18H84CV000537                1 Dove, Street         Dorchester, MA, 02125
# 9   18H84CV000547          56 Charles Street, 3         Dorchester, MA, 02122
# 10  18H84CV000548         16 Iroquois Street, 1   Roxbury Crossing, MA, 02120
# 11  18H84CV000550       48 Peninsula Place, 106         Dorchester, MA, 02125
# 12  18H84CV000551   1850 Washington Street, 709             Boston, MA, 02118
# 13  18H84CV000552       50 Fairlawn Avenue, E-7           Mattapan, MA, 02126
# 14  18H84CV000553
# 15  18H84CV000554         67 Cohasset Street, 2         Roslindale, MA, 02131
# 16  18H84CV000559      505 Congress Street, 308             Boston, MA, 02210
# 17  18H84CV000566           31 Jette Court, 759           Brighton, MA, 02135
# 18  18H84CV000567           90 Corbet Street, 2  Dorchester Center, MA, 02124
# 19  18H84CV000568       215 West Canton, Street             Boston, MA, 02116
# 20  18H84CV000570        293-295 Market, Street           Brighton, MA, 02135
# 21  18H84CV000574     968 Massachusetts, Avenue             Boston, MA, 02118
# 22  18H84SP004018       1288A Blue Hill, Avenue           Mattapan, MA, 02126
# 23  18H84SP004019           76 Clarke Avenue, 2            Chelsea, MA, 02150
# 24  18H84SP004020        30 Dalton Street, 1004             Boston, MA, 02115
# 25  18H84SP004021        30 Dalton Street, 2208             Boston, MA, 02115
# 26  18H84SP004022         660 Ocean Avenue, 418             Revere, MA, 02151
# 27  18H84SP004024          239 Garden Street, 2          Cambridge, MA, 02138
# 28  18H84SP004026          1370 Broadway, R 03N         Somerville, MA, 02144
# 29  18H84SP004027            1370 Broadway, 08D         Somerville, MA, 02144
# ..            ...                           ...                           ...
# 59  18H84SP004072         229 River Street, 301           Mattapan, MA, 02126
# 60  18H84SP004073      231 River Street, B1-104           Mattapan, MA, 02126
# 61  18H84SP004074         135 Spencer Street, 3  Dorchester Center, MA, 02124
# 62  18H84SP004076         48 Rosewood Street, 1           Mattapan, MA, 02126
# 63  18H84SP004079            2 Harlem Street, 3         Dorchester, MA, 02121
# 64  18H84SP004080     41 Waumbeck Street, RM 2R         Dorchester, MA, 02121
# 65  18H84SP004081          85 Esmond Street, 22         Dorchester, MA, 02121
# 66  18H84SP004082            85 Homes Avenue, 1         Dorchester, MA, 02122
# 67  18H84SP004083   522 Massachusetts Avenue, 2             Boston, MA, 02118
# 68  18H84SP004084   508 Massachusetts Avenue, 4             Boston, MA, 02118
# 69  18H84SP004085         415 River Street, 304           Mattapan, MA, 02126
# 70  18H84SP004087            95 Wayland, Street         Dorchester, MA, 02125
# 71  18H84SP004088         27 Greenock Street, 3  Dorchester Center, MA, 02124
# 72  18H84SP004089          68 Old Ironside, Way        Charlestown, MA, 02129
# 73  18H84SP004091        99B Old Ironsides, Way        Charlestown, MA, 02129
# 74  18H84SP004092         96 Old Ironsides, Way        Charlestown, MA, 02129
# 75  18H84SP004093         101 Canal Street, 409             Boston, MA, 02114
# 76  18H84SP004094         101 Canal Street, 821             Boston, MA, 02114
# 77  18H84SP004095    660 Washington Street, 18E             Boston, MA, 02111
# 78  18H84SP004096          50 Columbia Road, 10         Dorchester, MA, 02121
# 79  18H84SP004097      103 Washington Street, 9         Dorchester, MA, 02121
# 80  18H84SP004099         99 Lawrence Avenue, 1         Dorchester, MA, 02121
# 81  18H84SP004100           30 Gove Street, 204        East Boston, MA, 02128
# 82  18H84SP004103          184 Seaver Street, 6         Dorchester, MA, 02121
# 83  18H84SP004104       67 Brookledge Street, 4         Dorchester, MA, 02121
# 84  18H84SP004105        109 Hometead Street, 5         Dorchester, MA, 02121
# 85  18H84SP004106          144 Seaver Street, 7         Dorchester, MA, 02121
# 86  18H84SP004107        79 Hutchings Street, 3         Dorchester, MA, 02121
# 87  18H84SP004108        83 Hutchings Street, 3         Dorchester, MA, 02121
# 88  18H84SP004110       11 Brookledge Street, 8         Dorchester, MA, 02121
#
#      file date  close date                                          Defendant  \
# 0   09/04/2018  09/14/2018                                 [(Forde, Lotlene)]
# 1   09/04/2018  09/24/2018                         [(Ramos Rodriguez, Maria)]
# 2   09/05/2018  09/14/2018               [(Zhong Xing Long USA Investments,)]
# 3   09/05/2018  09/12/2018                      [(Boston Housing Authority,)]
# 4   09/05/2018  09/18/2018           [(Villalobos, Property Manager, Carmen)]
# 5   09/05/2018  09/18/2018  [(Lopes, Jose), (Lopes, Ricardo), (Lopes, Fran...
# 6   09/06/2018  09/18/2018                                   [(Ayala, Angel)]
# 7   09/06/2018  09/18/2018                   [(Murriel Toussaint, Rogera C.)]
# 8   09/06/2018  09/07/2018                                  [(Waite, Austin)]
# 9   09/12/2018  09/20/2018                           [(Blaisdell, Stephanie)]
# 10  09/12/2018  09/24/2018                             [(McKinlay, Shauneen)]
# 11  09/14/2018  09/28/2018                    [(Corcoran Jennison Dev. Co.,)]
# 12  09/17/2018  10/01/2018  [(Dejesus Osorio, Felipe), (Dejesus Osorio, De...
# 13  09/17/2018  09/24/2018                              [(Pugsley, Jennifer)]
# 14  09/18/2018  09/28/2018                               [(Gayle, Kerry-Ann)]
# 15  09/18/2018  10/03/2018                                 [(Buckley, Susan)]
# 16  09/20/2018  10/01/2018                               [(Burroughs, Casey)]
# 17  09/24/2018  09/24/2018      [(Jay Leary Manager of Corcoran Management,)]
# 18  09/24/2018  09/25/2018                                     [(Smith, Jim)]
# 19  09/25/2018  09/25/2018                                 [(Blinn, William)]
# 20  09/25/2018  10/02/2018                                [(Ferris, Shannon)]
# 21  09/26/2018  10/03/2018                            [(Rodriguez, Stefanie)]
# 22  09/04/2018  10/01/2018                            [(Octavius, Rodelaire)]
# 23  09/04/2018  09/17/2018              [(Turner, Lawanda), (Burton, Nicole)]
# 24  09/04/2018  09/13/2018                                      [(Bao, Yang)]
# 25  09/04/2018  09/18/2018                            [(Goldfeld, Frederico)]
# 26  09/04/2018  09/13/2018                               [(Chowdhury, Nidal)]
# 27  09/04/2018  09/13/2018                               [(Jackson, Felorah)]
# 28  09/04/2018  09/14/2018                                   [(Harvey, Taja)]
# 29  09/04/2018  09/14/2018                            [(Conoscienti, Thomas)]
# ..         ...         ...                                                ...
# 59  09/05/2018  09/13/2018                           [(Washington, Victoria)]
# 60  09/05/2018  09/14/2018                                  [(White, Elaine)]
# 61  09/05/2018  09/24/2018                                [(Johnson, Latoya)]
# 62  09/05/2018  10/02/2018                               [(Tyrance, Carissa)]
# 63  09/05/2018  10/05/2018                                    [(Jones, Dion)]
# 64  09/05/2018  10/01/2018                             [(Patterson, Crystal)]
# 65  09/05/2018  09/18/2018                              [(Batista, Yorkiris)]
# 66  09/05/2018  09/17/2018                            [(Raybine, Michael J.)]
# 67  09/05/2018  09/18/2018                                [(Creecy, Trannee)]
# 68  09/05/2018  09/18/2018                [(Monroig, Angel), (Salerno, Lisa)]
# 69  09/05/2018  10/01/2018                              [(Valentine, Sharon)]
# 70  09/05/2018  09/13/2018                                 [(Ocasio, Elenie)]
# 71  09/05/2018  09/21/2018                                   [(Renick, Ella)]
# 72  09/05/2018  09/13/2018                               [(Evans, Dominique)]
# 73  09/05/2018  09/13/2018                                 [(King Yau, Yung)]
# 74  09/05/2018  09/18/2018                                [(Jones, Jennifer)]
# 75  09/05/2018  09/14/2018               [(Ahmed, Muhammad), (Riaz, Ibrahim)]
# 76  09/05/2018  09/13/2018  [(Aravanis, Christos), (Deris, Alexander), (La...
# 77  09/05/2018  09/14/2018                           [(Bhagchandka, Anushka)]
# 78  09/05/2018  09/17/2018                              [(Castillo, Marisol)]
# 79  09/05/2018  09/18/2018                                [(Wright, Frankey)]
# 80  09/05/2018  09/14/2018                                    [(Pena, Sonia)]
# 81  09/05/2018  09/17/2018                                    [(Rios, Cindy)]
# 82  09/06/2018  09/14/2018                         [(Henderson, Tarshita R.)]
# 83  09/06/2018  09/13/2018                              [(Jackson, Kimberly)]
# 84  09/06/2018  09/13/2018                                [(Johnson, Tykeia)]
# 85  09/06/2018  09/14/2018                         [(Plaisival, Claudjah S.)]
# 86  09/06/2018  09/11/2018                              [(Price, Dominiquea)]
# 87  09/06/2018  09/14/2018                                 [(Pollard, Nikia)]
# 88  09/06/2018  09/13/2018      [(Rivera, Christiana), (Carrasquillo, Edwin)]
#
#                                             Plaintiff
# 0                                   [(Clarke, Sonia)]
# 1                     [(Ramos, Angel), (Jin, Xiaxia)]
# 2                                    [(Baez, Carmen)]
# 3                                   [(Allison, Rita)]
# 4                                    [(Deas, Cullen)]
# 5                               [(McDonald, Deneine)]
# 6                            [(Arch Development LP,)]
# 7                                [(Greene, Nieta M.)]
# 8                                [(Thompson, Samira)]
# 9                                  [(Sheals, Sandra)]
# 10                               [(Rossell, Haley A)]
# 11                                 [(McGeorge, John)]
# 12                              [(Grant Manor,L.P.,)]
# 13                                [(Moore, Naomi A.)]
# 14                      [(Frawley-Delle Apartments,)]
# 15        [(Miranda, Jonatas), (Schirick, Elizabeth)]
# 16               [(Waterside Development Group, LLC)]
# 17              [(Inspectional Services Department,)]
# 18                                [(Ingram, Monique)]
# 19                           [(Building Department,)]
# 20                          [(Cautilli, Carmelo Leo)]
# 21                                 [(Perdomo, Doris)]
# 22                              [(Denton, Gladstone)]
# 23                    [(Second City Properties, LLC)]
# 24                          [(PRG BD Investors, LLC)]
# 25                          [(PRG BD Investors, LLC)]
# 26                              [(64 VWS Owner, LLC)]
# 27                          [(POAH Communities, LLC)]
# 28                  [(Clarendon Hill Somerville LP,)]
# 29                  [(Clarendon Hill Somerville LP,)]
# ..                                                ...
# 59                        [(Trinity Management, LLC)]
# 60                        [(Trinity Management, LLC)]
# 61                                   [(Swaray, Jean)]
# 62                     [(Hill, Don), (Scott, Venice)]
# 63                                  [(Ross, Jane M.)]
# 64                                [(Harrison, Kevin)]
# 65                   [(The Community Builders, Inc.)]
# 66                          [(Pine Street Inn, Inc.)]
# 67              [(Tenants' Development Corporation,)]
# 68              [(Tenants' Development Corporation,)]
# 69                   [(Winn Managed Properties, LLC)]
# 70                   [(Winn Managed Properties, LLC)]
# 71                                 [(Castillo, Luis)]
# 72  [(The Cooperative of CharlesNEWtown Housing, I...
# 73  [(The Cooperative of CharlesNEWtown Housing, I...
# 74  [(The Cooperative of CharlesNEWtown Housing, I...
# 75             [(Equity Residential Management, LLC)]
# 76             [(Equity Residential Management, LLC)]
# 77             [(Equity Residential Management, LLC)]
# 78                     [(Washington Columbia II LP,)]
# 79                     [(Washington Columbia II LP,)]
# 80                           [(Quincy Geneva II LP,)]
# 81                      [(Metro Management Company,)]
# 82                       [(Maloney Properties Inc.,)]
# 83                       [(Maloney Properties Inc.,)]
# 84                       [(Maloney Properties Inc.,)]
# 85                       [(Maloney Properties Inc.,)]
# 86                       [(Maloney Properties Inc.,)]
# 87                       [(Maloney Properties Inc.,)]
# 88                       [(Maloney Properties Inc.,)]
#
# [89 rows x 7 columns]

# %%
df[df.case == "18H84SP004084"]
# Out:
#              case                       street               city   file date  \
# 68  18H84SP004084  508 Massachusetts Avenue, 4  Boston, MA, 02118  09/05/2018
#
#     close date                            Defendant  \
# 68  09/18/2018  [(Monroig, Angel), (Salerno, Lisa)]
#
#                                 Plaintiff
# 68  [(Tenants' Development Corporation,)]

# %%
df[df.case == "18H84SP004084"]["Defendant"]
# Out:
# 18H84SP004084    [Monroig, Angel, Salerno, Lisa]
# Name: Defendant, dtype: object

# %%
# saving our processed data to file
df.to_csv("court_data.csv")
